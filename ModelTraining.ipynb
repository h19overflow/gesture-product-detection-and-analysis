# %%
import cv2                       # Imports OpenCV for video capture and image processing
import mediapipe as mp           # Imports MediaPipe for hand detection and landmark estimation
import numpy as np               # Imports NumPy for array and mathematical operations
import math                      # Imports math for trigonometric and square root operations
from collections import deque, Counter  # Provides data structures for smoothing and frequency counting

# Initialize the MediaPipe Hands solution with detection and tracking confidence levels
mp_hands = mp.solutions.hands
mp_draw = mp.solutions.drawing_utils
hands = mp_hands.Hands(
    min_detection_confidence=0.5,   # Minimum confidence threshold for initial hand detection
    min_tracking_confidence=0.5     # Minimum confidence threshold for landmark tracking
)

# Define the landmark indices for each finger in MediaPipe Hands: MCP, PIP, DIP, TIP
FINGER_LANDMARKS = {
    "thumb":  [1, 2, 3, 4],     # Landmark indices for the thumb
    "index":  [5, 6, 7, 8],     # Landmark indices for the index finger
    "middle": [9, 10, 11, 12],  # Landmark indices for the middle finger
    "ring":   [13, 14, 15, 16], # Landmark indices for the ring finger
    "pinky":  [17, 18, 19, 20]  # Landmark indices for the pinky
}

def get_landmark_coords(hand_landmarks, index):
    """
    Returns the (x, y, z) coordinates of a specific landmark, given its index.
    """
    landmark = hand_landmarks.landmark[index]
    return np.array([landmark.x, landmark.y, landmark.z])

def vector(a, b):
    """
    Constructs a 3D vector going from point a to point b.
    """
    return b - a

def angle_between_points(a, b, c):
    """
    Calculates the angle formed at point b by the lines (a->b) and (b->c).
    Returns this angle in degrees.
    """
    ab = vector(b, a)
    cb = vector(b, c)
    dot_prod = np.dot(ab, cb)
    mag_ab = np.linalg.norm(ab)
    mag_cb = np.linalg.norm(cb)
    
    if mag_ab * mag_cb == 0:
        return 0.0  # Avoid division by zero
    
    cosine_angle = np.clip(dot_prod / (mag_ab * mag_cb), -1.0, 1.0)
    angle = np.degrees(np.arccos(cosine_angle))
    return angle

def is_finger_extended(hand_landmarks, finger_name, extension_threshold=160):
    """
    Determines if a particular finger is extended by measuring the angle at its PIP joint.
    If the angle is less than the extension_threshold (160 by default), we consider the finger extended.
    """
    indices = FINGER_LANDMARKS[finger_name]
    mcp_idx, pip_idx, dip_idx, tip_idx = indices
    
    mcp = get_landmark_coords(hand_landmarks, mcp_idx)
    pip = get_landmark_coords(hand_landmarks, pip_idx)
    tip = get_landmark_coords(hand_landmarks, tip_idx)

    angle_pip = angle_between_points(mcp, pip, tip)
    return angle_pip > extension_threshold

def detect_gesture(hand_landmarks):
    """
    Classifies the hand gesture using reversed logic:
      - "Pointing": Only the index finger is extended
      - "Neutral": No finger is extended
      - "Holding": Everything else
    """
    thumb_ext  = is_finger_extended(hand_landmarks, "thumb")
    index_ext  = is_finger_extended(hand_landmarks, "index")
    middle_ext = is_finger_extended(hand_landmarks, "middle")
    ring_ext   = is_finger_extended(hand_landmarks, "ring")
    pinky_ext  = is_finger_extended(hand_landmarks, "pinky")

    extended_fingers = sum([thumb_ext, index_ext, middle_ext, ring_ext, pinky_ext])

    # 1. Pointing: Only the index finger is extended
    if (index_ext
        and not thumb_ext
        and not middle_ext
        and not ring_ext
        and not pinky_ext):
        return "Pointing"

    # 2. Neutral: No finger is extended
    if extended_fingers == 0:
        return "Holding"

    # 3. Holding: Any other scenario
    return "Neutral"

# %% [markdown]
# ### **🔹 Key Features**
# ✅ **Uses MediaPipe Hands** for detecting and tracking **21 hand landmarks**.
# ✅ **Determines finger positions** by analyzing joint angles.
# ✅ **Classifies gestures dynamically** into predefined categories.
#
# ---
#
# ### **🔹 How It Works**
#
# 1. **Hand Detection (`mp_hands`)**
#    - Detects **21 hand landmarks** per hand.
#    - Tracks **fingers and joints** over time.
#
# 2. **Finger Landmark Definitions (`FINGER_LANDMARKS`)**
#    - Stores the key landmarks of each finger:
#      - **MCP** → Base joint
#      - **PIP** → Middle joint
#      - **DIP** → Near fingertip joint
#      - **TIP** → Fingertip
#
# 3. **Extract Landmark Coordinates (`get_landmark_coords()`)**
#    - Retrieves the **(x, y, z)** coordinates of any hand landmark.
#
# 4. **Calculate Finger Orientation (`vector()`, `angle_between_points()`)**
#    - Computes the **angle between joints** to check finger extension.
#
# 5. **Finger Extension Detection (`is_finger_extended()`)**
#    - A **finger is extended** if its **PIP joint angle** exceeds **160°**.
#
# 6. **Gesture Classification (`detect_gesture()`)**
#    - **"Pointing"** → Only the index finger is extended.
#    - **"Neutral"** → No fingers are extended.
#    - **"Holding"** → Any other combination of fingers extended.

# %%
# GESTURE_HISTORY_SIZE determines how many recent frames we keep to smooth out the classification
GESTURE_HISTORY_SIZE = 10

# Create a deque (double-ended queue) to store the most recent gesture results
gesture_history = deque(maxlen=GESTURE_HISTORY_SIZE)

# Start capturing video from the default webcam
cap = cv2.VideoCapture(0)

while cap.isOpened():                  # Continue until the webcam is closed or an error occurs
    success, frame = cap.read()        # Read a frame from the camera
    if not success:                    # If the frame is not read successfully, break the loop
        break

    frame = cv2.flip(frame, 1)         # Flip the frame horizontally for a mirror-like view
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # Convert the BGR frame to RGB for MediaPipe
    results = hands.process(rgb_frame)                  # Process the frame to detect hands

    current_gesture = "No Hand"        # Default gesture if no hand is detected
    if results.multi_hand_landmarks:   # If there's at least one hand detected
        # We only handle the first detected hand in this example
        hand_landmarks = results.multi_hand_landmarks[0]

        # Draw the detected hand landmarks on the frame
        mp_draw.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)

        # Determine the gesture using the reversed logic
        current_gesture = detect_gesture(hand_landmarks)

    # Append the current gesture to our history for smoothing
    gesture_history.append(current_gesture)
    # Find the most common gesture in the recent history to reduce classification flicker
    most_common_gesture = Counter(gesture_history).most_common(1)[0][0]

    # Show the smoothed gesture classification on the screen
    cv2.putText(
        frame,
        f"Gesture: {most_common_gesture}",
        (50, 50),
        cv2.FONT_HERSHEY_SIMPLEX,
        1,
        (0, 255, 0),
        2
    )

    # If there's at least one hand, display the number of extended fingers for debugging
    if results.multi_hand_landmarks:
        sum_extended = 0
        for name in FINGER_LANDMARKS.keys():
            ext = is_finger_extended(hand_landmarks, name)
            sum_extended += int(ext)
        cv2.putText(
            frame,
            f"Extended Fingers: {sum_extended}",
            (50, 100),
            cv2.FONT_HERSHEY_SIMPLEX,
            1,
            (0, 255, 255),
            2
        )

    # Display the augmented frame in a new window
    cv2.imshow("Reversed Logic Hand Gesture Detection", frame)

    # If 'q' is pressed, exit the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close the display window
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### **🔹 Key Features**
# ✅ **Real-time hand gesture detection using OpenCV and MediaPipe**.
# ✅ **Smooths gesture classification using a sliding window (`deque`)**.
# ✅ **Displays gesture type and number of extended fingers on the screen**.
#
# ---
#
# ### **🔹 How It Works**
#
# 1. **Gesture Smoothing with History (`gesture_history`)**
#    - Uses a **deque (double-ended queue)** to store the last **10 detected gestures**.
#    - **Finds the most common gesture** in recent frames to reduce flickering.
#
# 2. **Webcam Frame Processing (`cv2.VideoCapture(0)`)**
#    - Captures live video from the **default webcam**.
#    - **Flips the frame horizontally** for a natural, mirror-like view.
#    - **Converts the frame from BGR to RGB** for MediaPipe hand detection.
#
# 3. **Hand Detection & Gesture Classification (`detect_gesture()`)**
#    - Uses **MediaPipe Hands** to detect hand landmarks.
#    - If a hand is detected, **draws landmarks** on the frame.
#    - **Classifies the detected gesture** based on finger positions.
#
# 4. **Counting Extended Fingers (`is_finger_extended()`)**
#    - Iterates through all **five fingers** and checks if they are extended.
#    - Displays the **total number of extended fingers** on the screen.
#
# 5. **Displaying Information on Screen (`cv2.putText()`)**
#    - Shows the **most common gesture** from the last 10 frames.
#    - Shows **number of extended fingers** if a hand is detected.
#
# 6. **Live Video Feed (`cv2.imshow()`)**
#    - Continuously displays the processed video feed with **gesture classification overlays**.
#    - Press **'q' to exit** and close the webcam feed.
#
# 7. **Cleanup (`cap.release()` & `cv2.destroyAllWindows()`)**
#    - Properly releases the webcam and **closes all OpenCV windows** when exiting.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="JgNlmmfB1eTF3aW7fXFJ")
project = rf.workspace("product-detection-tcbq8").project("my-first-project-qdnml")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in My-First-Project-2 to yolov8:: 100%|██████████| 18505/18505 [00:05<00:00, 3202.76it/s]
# Extracting Dataset Version Zip to My-First-Project-2 in yolov8:: 100%|██████████| 654/654 [00:00<00:00, 1090.26it/s]

# %% [markdown]
# ### **🔹 Key Features**
# ✅ **Uses the Roboflow API** to download a YOLOv8 dataset.
# ✅ **Connects to a specific project inside a workspace**.
# ✅ **Downloads the dataset in the correct format for YOLOv8 training**.
#
# ---
#
# ### **🔹 How It Works**
#
# 1. **Initialize the Roboflow Client (`Roboflow(api_key)`)**
#    - Requires a **Roboflow API key** (`JgNlmmfB1eTF3aW7fXFJ` in this example).
#    - Connects to the **Roboflow cloud platform** to access datasets.
#
# 2. **Select the Project (`rf.workspace().project()`)**
#    - **Workspace:** `"product-detection-tcbq8"` (group of related projects).
#    - **Project Name:** `"my-first-project-qdnml"` (specific dataset being used).
#
# 3. **Specify the Dataset Version (`project.version(2)`)**
#    - Chooses **version 2** of the dataset (versions track different updates of a dataset).
#
# 4. **Download the Dataset (`version.download("yolov8")`)**
#    - Fetches the dataset in **YOLOv8 format**, making it **ready for training**.
#    - Automatically downloads and **extracts labeled images** to your local directory.
#
# ---
#
# ### **🔹 Notes**
# - The **API key should be kept secure**—avoid sharing publicly.
# - Ensure the **Roboflow workspace & project names are correct** to avoid errors.
# - The dataset is downloaded into the **current working directory**, so check the output folder after running this script.

# %%
from ultralytics import YOLO

# Load a YOLOv8 model (choose 'n' for nano version)
model = YOLO("yolov8n.pt")

# Train on your dataset
model.train(data=r"C:\Users\Adonis\OneDrive\Desktop\DataScience\Projects\MotionDetection\RoboFLow\My-First-Project-2\data.yaml", epochs=50)
# Out:
# New https://pypi.org/project/ultralytics/8.3.78 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.74  Python-3.11.11 torch-2.6.0+cpu CPU (AMD Ryzen 5 5600H with Radeon Graphics)
# engine\trainer: task=detect, mode=train, model=yolov8n.pt, data=C:\Users\Adonis\OneDrive\Desktop\DataScience\Projects\MotionDetection\My-First-Project-2\data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train2
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\Adonis\anaconda3\Lib\site-packages\ultralytics\engine\trainer.py:564, in BaseTrainer.get_dataset(self)
#     558 elif self.args.data.split(".")[-1] in {"yaml", "yml"} or self.args.task in {
#     559     "detect",
#     560     "segment",
#     561     "pose",
#     562     "obb",
#     563 }:
# --> 564     data = check_det_dataset(self.args.data)
#     565     if "yaml_file" in data:
#
# File c:\Users\Adonis\anaconda3\Lib\site-packages\ultralytics\data\utils.py:376, in check_det_dataset(dataset, autodownload)
#     375     m += f"\nNote dataset download directory is '{DATASETS_DIR}'. You can update this in '{SETTINGS_FILE}'"
# --> 376     raise FileNotFoundError(m)
#     377 t = time.time()
#
# FileNotFoundError:
# Dataset 'C://Users/Adonis/OneDrive/Desktop/DataScience/Projects/MotionDetection/My-First-Project-2/data.yaml' images not found ⚠️, missing path 'C:\Users\Adonis\OneDrive\Desktop\DataScience\Projects\MotionDetection\My-First-Project-2\valid\images'
# Note dataset download directory is 'C:\Users\Adonis\OneDrive\Desktop\DataScience\Projects\SuperMarket Traffic\datasets'. You can update this in 'C:\Users\Adonis\AppData\Roaming\Ultralytics\settings.json'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 7
#       4 model = YOLO("yolov8n.pt")
#       6 # Train on your dataset
# ----> 7 model.train(data=r"C:\Users\Adonis\OneDrive\Desktop\DataScience\Projects\MotionDetection\My-First-Project-2\data.yaml", epochs=50)
#
# File c:\Users\Adonis\anaconda3\Lib\site-packages\ultralytics\engine\model.py:803, in Model.train(self, trainer, **kwargs)
#     800 if args.get("resume"):
#     801     args["resume"] = self.ckpt_path
# --> 803 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     804 if not args.get("resume"):  # manually set model only if not resuming
#     805     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# File c:\Users\Adonis\anaconda3\Lib\site-packages\ultralytics\engine\trainer.py:134, in BaseTrainer.__init__(self, cfg, overrides, _callbacks)
#     132 self.model = check_model_file_from_stem(self.args.model)  # add suffix, i.e. yolo11n -> yolo11n.pt
#     133 with torch_distributed_zero_first(LOCAL_RANK):  # avoid auto-downloading dataset multiple times
# --> 134     self.trainset, self.testset = self.get_dataset()
#     135 self.ema = None
#     137 # Optimization utils init
#
# File c:\Users\Adonis\anaconda3\Lib\site-packages\ultralytics\engine\trainer.py:568, in BaseTrainer.get_dataset(self)
#     566             self.args.data = data["yaml_file"]  # for validating 'yolo train data=url.zip' usage
#     567 except Exception as e:
# --> 568     raise RuntimeError(emojis(f"Dataset '{clean_url(self.args.data)}' error ❌ {e}")) from e
#     569 self.data = data
#     570 return data["train"], data.get("val") or data.get("test")
#
# RuntimeError: Dataset 'C://Users/Adonis/OneDrive/Desktop/DataScience/Projects/MotionDetection/My-First-Project-2/data.yaml' error
# Dataset 'C://Users/Adonis/OneDrive/Desktop/DataScience/Projects/MotionDetection/My-First-Project-2/data.yaml' images not found , missing path 'C:\Users\Adonis\OneDrive\Desktop\DataScience\Projects\MotionDetection\My-First-Project-2\valid\images'
# Note dataset download directory is 'C:\Users\Adonis\OneDrive\Desktop\DataScience\Projects\SuperMarket Traffic\datasets'. You can update this in 'C:\Users\Adonis\AppData\Roaming\Ultralytics\settings.json'

# %% [markdown]
# ### **🔹 Key Features**
# ✅ **Loads YOLOv8 (Nano version) for object detection**.
# ✅ **Trains the model on a custom dataset from Roboflow**.
# ✅ **Runs for 50 epochs to optimize model performance**.
#
# ---
#
# ### **🔹 How It Works**
#
# 1. **Import YOLO from Ultralytics (`from ultralytics import YOLO`)**
#    - Loads the **YOLOv8 framework**, which supports training, validation, and inference.
#
# 2. **Load the YOLOv8 Model (`YOLO("yolov8n.pt")`)**
#    - Uses the **Nano version (`yolov8n.pt`)**, which is lightweight and fast.
#    - Suitable for **real-time applications** on devices with limited computational power.
#
# 3. **Train the Model (`model.train()`)**
#    - **Dataset File:** `data.yaml` → Contains dataset paths, class labels, and configurations.
#    - **Training Directory:** `C:\Users\Adonis\OneDrive\Desktop\DataScience\Projects\MotionDetection\RoboFLow\My-First-Project-2\`
#    - **Epochs:** `50` → The number of times the model sees the dataset to learn features.
#    - **During training**, YOLO:
#      - Loads labeled images from the dataset.
#      - Performs **augmentation** to improve generalization.
#      - **Optimizes weights** for object detection.
#
# ---
#
# ### **🔹 Notes**
# - Ensure that **`data.yaml` is correctly formatted** with dataset paths and class names.
# - The number of epochs (`epochs=50`) can be **increased for better accuracy** or **decreased for faster training**.
# - After training, the **best model weights** will be saved (e.g., `runs/train/exp/weights/best.pt`).
# - This model can later be used for **real-time detection** in videos or images.

# %%
import cv2
from ultralytics import YOLO

# Load the trained YOLOv8 model
model = YOLO(r"C:\Users\Adonis\OneDrive\Desktop\DataScience\Projects\MotionDetection\detect\train11\weights\best.pt")

# Initialize webcam (0 = default camera)
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Inference
    results = model.predict(frame, conf=0.8)  # set your preferred confidence threshold

    # Copy the frame so we can draw on it
    annotated_frame = frame.copy()

    # results is a list, but there's only one item for a single frame
    detections = results[0]

    # Loop through each detection
    for box in detections.boxes:
        # box.xyxy[0] -> [x1, y1, x2, y2]
        x1, y1, x2, y2 = box.xyxy[0]
        # Convert to integer
        x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

        # box.cls[0] -> class index, box.conf[0] -> confidence
        cls_id = int(box.cls[0])
        conf = float(box.conf[0])

        # Get class name using the model's names dictionary
        class_name = model.names[cls_id]

        # Draw bounding box
        color = (255, 0, 0)  # BGR: Blue
        cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), color, 2)

        # Create label text
        label = f"{class_name} {conf:.2f}"

        # Draw label background box for better text visibility
        (text_width, text_height), baseline = cv2.getTextSize(
            label, cv2.FONT_HERSHEY_SIMPLEX, 0.5, 2
        )
        cv2.rectangle(
            annotated_frame, 
            (x1, y1 - text_height - 10), 
            (x1 + text_width, y1), 
            color, 
            -1
        )
        
        # Put label text above bounding box
        cv2.putText(
            annotated_frame, 
            label, 
            (x1, y1 - 5), 
            cv2.FONT_HERSHEY_SIMPLEX, 
            0.5, 
            (255, 255, 255),  # White text
            2
        )

    # Show the annotated frame
    cv2.imshow("YOLOv8 Real-Time Detection", annotated_frame)

    # Press ESC key to quit
    if cv2.waitKey(1) & 0xFF == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 151.4ms
# Speed: 8.7ms preprocess, 151.4ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 144.7ms
# Speed: 4.5ms preprocess, 144.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.4ms
# Speed: 3.0ms preprocess, 78.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.2ms
# Speed: 2.0ms preprocess, 76.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 67.9ms
# Speed: 1.0ms preprocess, 67.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 69.5ms
# Speed: 2.5ms preprocess, 69.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 69.3ms
# Speed: 1.5ms preprocess, 69.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 62.1ms
# Speed: 2.0ms preprocess, 62.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.8ms
# Speed: 2.5ms preprocess, 57.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.1ms
# Speed: 3.0ms preprocess, 61.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.2ms
# Speed: 2.0ms preprocess, 63.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 62.6ms
# Speed: 1.0ms preprocess, 62.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.2ms
# Speed: 1.4ms preprocess, 61.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 62.6ms
# Speed: 1.0ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.5ms
# Speed: 1.5ms preprocess, 58.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.3ms
# Speed: 1.0ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.7ms
# Speed: 2.0ms preprocess, 58.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.3ms
# Speed: 1.0ms preprocess, 60.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.4ms
# Speed: 1.0ms preprocess, 58.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.2ms
# Speed: 1.3ms preprocess, 54.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.6ms
# Speed: 0.9ms preprocess, 88.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.8ms
# Speed: 2.0ms preprocess, 61.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.9ms
# Speed: 1.5ms preprocess, 55.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.5ms
# Speed: 1.5ms preprocess, 63.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.5ms
# Speed: 1.5ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.6ms
# Speed: 1.0ms preprocess, 59.6ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.9ms
# Speed: 2.1ms preprocess, 57.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.9ms
# Speed: 1.0ms preprocess, 55.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.9ms
# Speed: 2.0ms preprocess, 53.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.4ms
# Speed: 2.5ms preprocess, 59.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 62.0ms
# Speed: 1.0ms preprocess, 62.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.9ms
# Speed: 1.0ms preprocess, 57.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.1ms
# Speed: 2.9ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.1ms
# Speed: 1.0ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 72.7ms
# Speed: 2.1ms preprocess, 72.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.0ms
# Speed: 1.9ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.0ms
# Speed: 1.5ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.3ms
# Speed: 2.0ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.0ms
# Speed: 1.0ms preprocess, 58.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.7ms
# Speed: 1.0ms preprocess, 57.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.9ms
# Speed: 1.0ms preprocess, 58.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.0ms
# Speed: 2.5ms preprocess, 56.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.7ms
# Speed: 1.0ms preprocess, 56.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.3ms
# Speed: 1.0ms preprocess, 58.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.7ms
# Speed: 2.1ms preprocess, 57.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.7ms
# Speed: 2.0ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.9ms
# Speed: 2.0ms preprocess, 57.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.7ms
# Speed: 2.1ms preprocess, 56.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.8ms
# Speed: 1.5ms preprocess, 56.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.7ms
# Speed: 1.0ms preprocess, 56.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.3ms
# Speed: 2.3ms preprocess, 58.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.1ms
# Speed: 1.6ms preprocess, 55.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 113.4ms
# Speed: 1.0ms preprocess, 113.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.2ms
# Speed: 2.1ms preprocess, 56.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.1ms
# Speed: 1.5ms preprocess, 57.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.5ms
# Speed: 1.5ms preprocess, 57.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.6ms
# Speed: 2.0ms preprocess, 60.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.7ms
# Speed: 2.0ms preprocess, 58.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.8ms
# Speed: 1.5ms preprocess, 60.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.7ms
# Speed: 1.5ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.4ms
# Speed: 2.0ms preprocess, 56.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.7ms
# Speed: 1.1ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.0ms
# Speed: 1.8ms preprocess, 60.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.3ms
# Speed: 2.6ms preprocess, 58.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.9ms
# Speed: 1.0ms preprocess, 56.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.4ms
# Speed: 1.3ms preprocess, 59.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.5ms
# Speed: 1.0ms preprocess, 57.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.8ms
# Speed: 1.5ms preprocess, 57.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.3ms
# Speed: 1.0ms preprocess, 58.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.3ms
# Speed: 1.0ms preprocess, 60.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.8ms
# Speed: 1.2ms preprocess, 57.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.8ms
# Speed: 1.0ms preprocess, 58.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.3ms
# Speed: 1.5ms preprocess, 58.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.7ms
# Speed: 1.0ms preprocess, 57.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.6ms
# Speed: 1.0ms preprocess, 59.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.2ms
# Speed: 1.0ms preprocess, 57.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.3ms
# Speed: 2.2ms preprocess, 55.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.3ms
# Speed: 2.0ms preprocess, 56.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.4ms
# Speed: 1.5ms preprocess, 58.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.3ms
# Speed: 1.3ms preprocess, 56.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.3ms
# Speed: 2.0ms preprocess, 60.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 65.2ms
# Speed: 1.0ms preprocess, 65.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 65.2ms
# Speed: 2.0ms preprocess, 65.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 81.3ms
# Speed: 1.0ms preprocess, 81.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.8ms
# Speed: 1.5ms preprocess, 56.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.1ms
# Speed: 1.0ms preprocess, 58.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 82.3ms
# Speed: 1.3ms preprocess, 82.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.0ms
# Speed: 1.4ms preprocess, 59.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.4ms
# Speed: 0.9ms preprocess, 60.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.1ms
# Speed: 1.5ms preprocess, 55.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.2ms
# Speed: 1.2ms preprocess, 59.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.9ms
# Speed: 2.0ms preprocess, 58.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.7ms
# Speed: 1.5ms preprocess, 57.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.4ms
# Speed: 1.5ms preprocess, 57.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.5ms
# Speed: 1.8ms preprocess, 63.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.8ms
# Speed: 1.0ms preprocess, 60.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.8ms
# Speed: 1.5ms preprocess, 51.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.3ms
# Speed: 1.0ms preprocess, 53.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.7ms
# Speed: 2.0ms preprocess, 57.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.1ms
# Speed: 1.5ms preprocess, 52.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.8ms
# Speed: 2.4ms preprocess, 50.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.9ms
# Speed: 1.0ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.9ms
# Speed: 1.4ms preprocess, 54.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.7ms
# Speed: 1.9ms preprocess, 55.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.0ms
# Speed: 2.4ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.2ms
# Speed: 2.5ms preprocess, 55.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.5ms
# Speed: 1.5ms preprocess, 57.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.6ms
# Speed: 1.5ms preprocess, 56.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.7ms
# Speed: 1.5ms preprocess, 51.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.3ms
# Speed: 0.9ms preprocess, 54.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.3ms
# Speed: 2.1ms preprocess, 54.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.9ms
# Speed: 2.6ms preprocess, 57.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.4ms
# Speed: 1.1ms preprocess, 54.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.3ms
# Speed: 2.2ms preprocess, 52.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 65.1ms
# Speed: 1.0ms preprocess, 65.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.7ms
# Speed: 2.0ms preprocess, 63.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.0ms
# Speed: 1.5ms preprocess, 55.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.4ms
# Speed: 1.5ms preprocess, 50.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.5ms
# Speed: 1.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.0ms
# Speed: 2.6ms preprocess, 52.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.4ms
# Speed: 1.0ms preprocess, 55.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 67.9ms
# Speed: 1.0ms preprocess, 67.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.7ms
# Speed: 2.6ms preprocess, 51.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.0ms
# Speed: 1.5ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.7ms
# Speed: 1.5ms preprocess, 54.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.3ms
# Speed: 1.0ms preprocess, 55.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.7ms
# Speed: 2.0ms preprocess, 50.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.5ms
# Speed: 2.1ms preprocess, 54.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.0ms
# Speed: 1.0ms preprocess, 53.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.6ms
# Speed: 2.4ms preprocess, 52.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.8ms
# Speed: 2.0ms preprocess, 50.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.6ms
# Speed: 2.1ms preprocess, 51.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.4ms
# Speed: 1.0ms preprocess, 52.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 49.9ms
# Speed: 2.0ms preprocess, 49.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 69.0ms
# Speed: 1.0ms preprocess, 69.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.4ms
# Speed: 1.0ms preprocess, 50.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 49.9ms
# Speed: 1.5ms preprocess, 49.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.7ms
# Speed: 1.4ms preprocess, 52.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.3ms
# Speed: 2.2ms preprocess, 51.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.2ms
# Speed: 2.0ms preprocess, 57.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.4ms
# Speed: 1.3ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.0ms
# Speed: 1.1ms preprocess, 55.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.0ms
# Speed: 1.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.2ms
# Speed: 1.0ms preprocess, 55.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.0ms
# Speed: 1.0ms preprocess, 87.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.9ms
# Speed: 1.5ms preprocess, 57.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.1ms
# Speed: 1.0ms preprocess, 58.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.1ms
# Speed: 1.8ms preprocess, 57.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.4ms
# Speed: 2.6ms preprocess, 54.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.5ms
# Speed: 1.0ms preprocess, 59.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.5ms
# Speed: 1.0ms preprocess, 57.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.1ms
# Speed: 0.8ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.8ms
# Speed: 2.5ms preprocess, 54.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.7ms
# Speed: 2.1ms preprocess, 55.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.2ms
# Speed: 1.0ms preprocess, 55.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.2ms
# Speed: 2.0ms preprocess, 53.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.8ms
# Speed: 2.0ms preprocess, 54.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.6ms
# Speed: 1.5ms preprocess, 58.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.6ms
# Speed: 1.5ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.4ms
# Speed: 1.3ms preprocess, 57.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.6ms
# Speed: 1.0ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.9ms
# Speed: 1.1ms preprocess, 55.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.1ms
# Speed: 1.5ms preprocess, 56.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.4ms
# Speed: 2.0ms preprocess, 55.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.0ms
# Speed: 1.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.2ms
# Speed: 1.0ms preprocess, 57.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.6ms
# Speed: 1.0ms preprocess, 61.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.1ms
# Speed: 1.2ms preprocess, 60.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.1ms
# Speed: 2.1ms preprocess, 56.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.5ms
# Speed: 1.5ms preprocess, 61.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.3ms
# Speed: 1.0ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.7ms
# Speed: 1.0ms preprocess, 61.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.3ms
# Speed: 2.0ms preprocess, 77.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 64.4ms
# Speed: 2.0ms preprocess, 64.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 65.0ms
# Speed: 1.1ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 62.6ms
# Speed: 1.5ms preprocess, 62.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 67.7ms
# Speed: 2.0ms preprocess, 67.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.8ms
# Speed: 2.5ms preprocess, 61.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.1ms
# Speed: 2.0ms preprocess, 63.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.4ms
# Speed: 1.6ms preprocess, 55.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.4ms
# Speed: 1.0ms preprocess, 57.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.4ms
# Speed: 1.4ms preprocess, 89.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.2ms
# Speed: 1.2ms preprocess, 59.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.7ms
# Speed: 1.6ms preprocess, 60.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 64.2ms
# Speed: 2.0ms preprocess, 64.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.3ms
# Speed: 2.1ms preprocess, 60.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 67.1ms
# Speed: 2.0ms preprocess, 67.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 66.2ms
# Speed: 2.0ms preprocess, 66.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.7ms
# Speed: 2.1ms preprocess, 59.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.3ms
# Speed: 1.2ms preprocess, 57.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.9ms
# Speed: 1.0ms preprocess, 55.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.6ms
# Speed: 1.5ms preprocess, 59.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.4ms
# Speed: 1.0ms preprocess, 59.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.5ms
# Speed: 1.0ms preprocess, 60.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.3ms
# Speed: 1.0ms preprocess, 60.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.0ms
# Speed: 1.5ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.7ms
# Speed: 2.3ms preprocess, 60.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.9ms
# Speed: 2.1ms preprocess, 55.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 104.0ms
# Speed: 2.0ms preprocess, 104.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.5ms
# Speed: 1.0ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.9ms
# Speed: 2.5ms preprocess, 57.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.8ms
# Speed: 1.3ms preprocess, 88.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 97.0ms
# Speed: 2.0ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 84.4ms
# Speed: 2.0ms preprocess, 84.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 74.9ms
# Speed: 2.0ms preprocess, 74.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.6ms
# Speed: 1.0ms preprocess, 78.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 69.9ms
# Speed: 1.6ms preprocess, 69.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 73.5ms
# Speed: 2.0ms preprocess, 73.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 67.7ms
# Speed: 3.4ms preprocess, 67.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 69.6ms
# Speed: 3.0ms preprocess, 69.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.4ms
# Speed: 1.5ms preprocess, 76.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 79.1ms
# Speed: 2.0ms preprocess, 79.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 67.3ms
# Speed: 2.0ms preprocess, 67.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 64.7ms
# Speed: 1.5ms preprocess, 64.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 72.4ms
# Speed: 1.0ms preprocess, 72.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 65.9ms
# Speed: 2.2ms preprocess, 65.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 102.6ms
# Speed: 4.0ms preprocess, 102.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 106.2ms
# Speed: 3.0ms preprocess, 106.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 79.3ms
# Speed: 4.0ms preprocess, 79.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 75.3ms
# Speed: 2.0ms preprocess, 75.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 79.9ms
# Speed: 2.0ms preprocess, 79.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.9ms
# Speed: 2.0ms preprocess, 76.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 84.1ms
# Speed: 3.0ms preprocess, 84.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.5ms
# Speed: 3.0ms preprocess, 78.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 80.4ms
# Speed: 2.0ms preprocess, 80.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 91.4ms
# Speed: 1.5ms preprocess, 91.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 93.0ms
# Speed: 2.6ms preprocess, 93.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 92.9ms
# Speed: 2.0ms preprocess, 92.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 90.6ms
# Speed: 2.0ms preprocess, 90.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 80.4ms
# Speed: 2.0ms preprocess, 80.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 120.5ms
# Speed: 3.0ms preprocess, 120.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 79.4ms
# Speed: 3.0ms preprocess, 79.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.6ms
# Speed: 3.0ms preprocess, 77.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.0ms
# Speed: 2.0ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.8ms
# Speed: 2.0ms preprocess, 76.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 79.4ms
# Speed: 2.0ms preprocess, 79.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 81.9ms
# Speed: 2.0ms preprocess, 81.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 94.6ms
# Speed: 2.0ms preprocess, 94.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.1ms
# Speed: 2.0ms preprocess, 87.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.4ms
# Speed: 2.0ms preprocess, 76.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 80.4ms
# Speed: 1.5ms preprocess, 80.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 82.4ms
# Speed: 2.0ms preprocess, 82.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.5ms
# Speed: 2.0ms preprocess, 78.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 81.9ms
# Speed: 3.0ms preprocess, 81.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 74.7ms
# Speed: 2.0ms preprocess, 74.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 70.3ms
# Speed: 2.0ms preprocess, 70.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 71.4ms
# Speed: 1.1ms preprocess, 71.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 65.7ms
# Speed: 2.0ms preprocess, 65.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.2ms
# Speed: 2.0ms preprocess, 88.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 65.5ms
# Speed: 2.0ms preprocess, 65.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.8ms
# Speed: 2.0ms preprocess, 88.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 96.1ms
# Speed: 2.0ms preprocess, 96.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 111.4ms
# Speed: 2.0ms preprocess, 111.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 98.8ms
# Speed: 3.3ms preprocess, 98.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 152.8ms
# Speed: 2.0ms preprocess, 152.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 130.8ms
# Speed: 3.0ms preprocess, 130.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 118.3ms
# Speed: 3.0ms preprocess, 118.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 91.5ms
# Speed: 2.0ms preprocess, 91.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 102.7ms
# Speed: 4.0ms preprocess, 102.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 125.7ms
# Speed: 2.5ms preprocess, 125.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 98.0ms
# Speed: 5.0ms preprocess, 98.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 119.6ms
# Speed: 2.0ms preprocess, 119.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 136.0ms
# Speed: 3.0ms preprocess, 136.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 96.5ms
# Speed: 2.0ms preprocess, 96.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 116.4ms
# Speed: 2.0ms preprocess, 116.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 109.1ms
# Speed: 4.0ms preprocess, 109.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 169.1ms
# Speed: 2.0ms preprocess, 169.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 135.9ms
# Speed: 4.0ms preprocess, 135.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 102.6ms
# Speed: 3.0ms preprocess, 102.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 151.6ms
# Speed: 4.0ms preprocess, 151.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 193.3ms
# Speed: 2.0ms preprocess, 193.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 133.4ms
# Speed: 2.0ms preprocess, 133.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.7ms
# Speed: 4.0ms preprocess, 121.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 140.5ms
# Speed: 3.0ms preprocess, 140.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 119.7ms
# Speed: 2.0ms preprocess, 119.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 121.4ms
# Speed: 2.0ms preprocess, 121.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 130.1ms
# Speed: 4.2ms preprocess, 130.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 136.0ms
# Speed: 3.0ms preprocess, 136.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 134.8ms
# Speed: 3.5ms preprocess, 134.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 123.4ms
# Speed: 2.0ms preprocess, 123.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 101.9ms
# Speed: 3.4ms preprocess, 101.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 108.6ms
# Speed: 2.0ms preprocess, 108.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 123.4ms
# Speed: 4.1ms preprocess, 123.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 100.0ms
# Speed: 3.0ms preprocess, 100.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 164.7ms
# Speed: 2.5ms preprocess, 164.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 104.7ms
# Speed: 2.0ms preprocess, 104.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 119.3ms
# Speed: 4.1ms preprocess, 119.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 111.8ms
# Speed: 3.0ms preprocess, 111.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 111.2ms
# Speed: 2.0ms preprocess, 111.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 136.6ms
# Speed: 4.0ms preprocess, 136.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 117.9ms
# Speed: 3.0ms preprocess, 117.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 108.8ms
# Speed: 2.6ms preprocess, 108.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 99.1ms
# Speed: 3.0ms preprocess, 99.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 106.2ms
# Speed: 2.0ms preprocess, 106.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 99.1ms
# Speed: 2.0ms preprocess, 99.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 97.5ms
# Speed: 2.0ms preprocess, 97.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 91.3ms
# Speed: 3.0ms preprocess, 91.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 111.7ms
# Speed: 2.0ms preprocess, 111.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 125.2ms
# Speed: 2.0ms preprocess, 125.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 86.7ms
# Speed: 2.6ms preprocess, 86.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 93.0ms
# Speed: 1.5ms preprocess, 93.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 90.0ms
# Speed: 2.0ms preprocess, 90.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 120.3ms
# Speed: 1.3ms preprocess, 120.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 85.1ms
# Speed: 2.0ms preprocess, 85.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 89.0ms
# Speed: 2.0ms preprocess, 89.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 96.9ms
# Speed: 4.0ms preprocess, 96.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 89.1ms
# Speed: 2.0ms preprocess, 89.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 97.7ms
# Speed: 2.0ms preprocess, 97.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 109.1ms
# Speed: 3.0ms preprocess, 109.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 84.7ms
# Speed: 3.0ms preprocess, 84.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 93.8ms
# Speed: 2.0ms preprocess, 93.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 96.1ms
# Speed: 2.0ms preprocess, 96.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 83.2ms
# Speed: 3.0ms preprocess, 83.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 96.6ms
# Speed: 3.0ms preprocess, 96.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 160.9ms
# Speed: 2.0ms preprocess, 160.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 96.9ms
# Speed: 2.0ms preprocess, 96.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 79.5ms
# Speed: 2.0ms preprocess, 79.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 90.1ms
# Speed: 2.0ms preprocess, 90.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 84.4ms
# Speed: 2.0ms preprocess, 84.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 107.2ms
# Speed: 2.5ms preprocess, 107.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 85.1ms
# Speed: 2.5ms preprocess, 85.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 85.5ms
# Speed: 2.5ms preprocess, 85.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 85.5ms
# Speed: 2.0ms preprocess, 85.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 78.4ms
# Speed: 1.0ms preprocess, 78.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 97.8ms
# Speed: 2.0ms preprocess, 97.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 86.9ms
# Speed: 2.0ms preprocess, 86.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 88.9ms
# Speed: 2.0ms preprocess, 88.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 101.2ms
# Speed: 2.0ms preprocess, 101.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 110.0ms
# Speed: 2.0ms preprocess, 110.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 100.1ms
# Speed: 2.0ms preprocess, 100.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 92.1ms
# Speed: 2.0ms preprocess, 92.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 98.6ms
# Speed: 3.0ms preprocess, 98.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.8ms
# Speed: 1.6ms preprocess, 85.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 93.6ms
# Speed: 2.1ms preprocess, 93.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 74.4ms
# Speed: 2.0ms preprocess, 74.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 93.0ms
# Speed: 2.0ms preprocess, 93.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 101.1ms
# Speed: 2.0ms preprocess, 101.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 92.2ms
# ...
# Speed: 2.0ms preprocess, 66.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 63.4ms
# Speed: 2.0ms preprocess, 63.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 60.7ms
# Speed: 1.5ms preprocess, 60.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 57.6ms
# Speed: 1.0ms preprocess, 57.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 59.2ms
# Speed: 1.1ms preprocess, 59.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 61.0ms
# Speed: 1.6ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 75.0ms
# Speed: 2.0ms preprocess, 75.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 67.4ms
# Speed: 1.0ms preprocess, 67.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 58.8ms
# Speed: 2.0ms preprocess, 58.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 57.8ms
# Speed: 2.0ms preprocess, 57.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 59.2ms
# Speed: 2.0ms preprocess, 59.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 55.6ms
# Speed: 1.0ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 58.5ms
# Speed: 1.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 75.0ms
# Speed: 1.3ms preprocess, 75.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 55.2ms
# Speed: 2.0ms preprocess, 55.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 55.1ms
# Speed: 2.0ms preprocess, 55.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 58.8ms
# Speed: 2.0ms preprocess, 58.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 59.9ms
# Speed: 1.0ms preprocess, 59.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 57.0ms
# Speed: 1.2ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 59.0ms
# Speed: 1.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 58.3ms
# Speed: 1.1ms preprocess, 58.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 55.9ms
# Speed: 1.0ms preprocess, 55.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 52.9ms
# Speed: 2.2ms preprocess, 52.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 54.8ms
# Speed: 1.0ms preprocess, 54.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 55.1ms
# Speed: 1.5ms preprocess, 55.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 54.2ms
# Speed: 1.3ms preprocess, 54.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 54.5ms
# Speed: 1.5ms preprocess, 54.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 59.4ms
# Speed: 2.0ms preprocess, 59.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 55.7ms
# Speed: 2.1ms preprocess, 55.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 53.8ms
# Speed: 1.4ms preprocess, 53.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 54.7ms
# Speed: 1.5ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 58.2ms
# Speed: 1.0ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 57.2ms
# Speed: 1.0ms preprocess, 57.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 60.5ms
# Speed: 1.5ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 62.1ms
# Speed: 1.4ms preprocess, 62.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 89.5ms
# Speed: 2.0ms preprocess, 89.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 62.3ms
# Speed: 1.0ms preprocess, 62.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 97.2ms
# Speed: 3.0ms preprocess, 97.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 56.7ms
# Speed: 1.0ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 56.3ms
# Speed: 1.5ms preprocess, 56.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.1ms
# Speed: 1.5ms preprocess, 53.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.2ms
# Speed: 1.0ms preprocess, 53.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.8ms
# Speed: 1.0ms preprocess, 55.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.4ms
# Speed: 1.5ms preprocess, 54.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.7ms
# Speed: 1.0ms preprocess, 60.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.5ms
# Speed: 1.5ms preprocess, 56.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 59.9ms
# Speed: 2.0ms preprocess, 59.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.9ms
# Speed: 2.4ms preprocess, 61.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.6ms
# Speed: 2.0ms preprocess, 60.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 60.0ms
# Speed: 2.3ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.9ms
# Speed: 1.0ms preprocess, 61.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.6ms
# Speed: 1.6ms preprocess, 58.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.8ms
# Speed: 1.6ms preprocess, 61.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.4ms
# Speed: 2.0ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 84.3ms
# Speed: 2.0ms preprocess, 84.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.2ms
# Speed: 1.0ms preprocess, 59.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.2ms
# Speed: 2.5ms preprocess, 56.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.2ms
# Speed: 3.0ms preprocess, 53.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.9ms
# Speed: 1.0ms preprocess, 56.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.6ms
# Speed: 1.0ms preprocess, 57.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.6ms
# Speed: 1.2ms preprocess, 56.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.6ms
# Speed: 1.0ms preprocess, 55.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.9ms
# Speed: 1.0ms preprocess, 59.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.6ms
# Speed: 1.4ms preprocess, 57.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.5ms
# Speed: 1.4ms preprocess, 77.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.4ms
# Speed: 2.5ms preprocess, 58.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.5ms
# Speed: 1.0ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.8ms
# Speed: 1.0ms preprocess, 59.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.2ms
# Speed: 1.0ms preprocess, 59.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.7ms
# Speed: 1.2ms preprocess, 57.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.4ms
# Speed: 1.0ms preprocess, 59.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 82.6ms
# Speed: 1.0ms preprocess, 82.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 66.5ms
# Speed: 2.0ms preprocess, 66.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.3ms
# Speed: 1.0ms preprocess, 59.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.1ms
# Speed: 2.0ms preprocess, 56.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.4ms
# Speed: 2.3ms preprocess, 59.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.0ms
# Speed: 1.1ms preprocess, 59.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.1ms
# Speed: 3.0ms preprocess, 60.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.8ms
# Speed: 2.0ms preprocess, 56.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.9ms
# Speed: 1.0ms preprocess, 59.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.9ms
# Speed: 1.5ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.6ms
# Speed: 2.8ms preprocess, 57.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.1ms
# Speed: 3.0ms preprocess, 60.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.4ms
# Speed: 1.0ms preprocess, 57.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.0ms
# Speed: 1.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 66.1ms
# Speed: 2.2ms preprocess, 66.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.9ms
# Speed: 1.0ms preprocess, 59.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.1ms
# Speed: 1.5ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.4ms
# Speed: 2.4ms preprocess, 59.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.8ms
# Speed: 1.5ms preprocess, 57.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.5ms
# Speed: 1.0ms preprocess, 57.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.9ms
# Speed: 1.6ms preprocess, 88.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.3ms
# Speed: 1.5ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 65.3ms
# Speed: 1.0ms preprocess, 65.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.3ms
# Speed: 2.0ms preprocess, 60.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.8ms
# Speed: 1.0ms preprocess, 56.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.9ms
# Speed: 1.0ms preprocess, 56.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.7ms
# Speed: 2.0ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.4ms
# Speed: 1.4ms preprocess, 53.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 58.9ms
# Speed: 1.0ms preprocess, 58.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.9ms
# Speed: 2.0ms preprocess, 57.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.3ms
# Speed: 1.6ms preprocess, 60.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 66.8ms
# Speed: 2.5ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 70.3ms
# Speed: 2.0ms preprocess, 70.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 68.6ms
# Speed: 2.0ms preprocess, 68.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.5ms
# Speed: 1.6ms preprocess, 63.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 79.7ms
# Speed: 1.0ms preprocess, 79.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.4ms
# Speed: 2.0ms preprocess, 76.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 66.8ms
# Speed: 2.5ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.9ms
# Speed: 1.0ms preprocess, 59.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.9ms
# Speed: 1.0ms preprocess, 60.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.2ms
# Speed: 2.3ms preprocess, 59.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.2ms
# Speed: 2.0ms preprocess, 78.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# ### **🔹 Key Features**
# ✅ **Loads a trained YOLOv8 model for real-time object detection**.
# ✅ **Captures live video from the webcam and processes each frame**.
# ✅ **Draws bounding boxes and labels around detected objects**.
# ✅ **Displays confidence scores to indicate detection certainty**.
#
# ---
#
# ### **🔹 How It Works**
#
# 1. **Load the Trained YOLOv8 Model (`YOLO(best.pt)`)**
#    - Uses a **custom-trained YOLOv8 model** (`best.pt`) to recognize objects.
#    - The model is located at:
#      ```
#      C:\Users\Adonis\OneDrive\Desktop\DataScience\Projects\MotionDetection\detect\train11\weights\best.pt
#      ```
#    - **Ensures the model is trained and available before running detection.**
#
# 2. **Capture Live Video (`cv2.VideoCapture(0)`)**
#    - Uses the **default webcam** (`0`) for real-time detection.
#    - Reads frames in a continuous loop.
#
# 3. **Run YOLOv8 Inference (`model.predict()`)**
#    - Processes each frame and predicts objects with **confidence ≥ 0.8**.
#    - `results[0]` contains detected bounding boxes, class IDs, and confidence scores.
#
# 4. **Extract & Draw Bounding Boxes**
#    - Extracts **coordinates (`x1, y1, x2, y2`)** for each detected object.
#    - Draws a **blue rectangle (`(255, 0, 0)`)** around the detected object.
#    - Fetches the **class name from `model.names[]`** and displays it.
#
# 5. **Overlay Detection Labels**
#    - Displays the **object name + confidence score** above the bounding box.
#    - Uses a **background box** behind the text to improve visibility.
#
# 6. **Display the Processed Frame (`cv2.imshow()`)**
#    - Shows the **annotated video feed** in a new window.
#    - **Updates dynamically** as new frames are processed.
#
# 7. **Exit on ESC Key (`cv2.waitKey(1)`)**
#    - Press **ESC (`27`)** to close the detection window.
#    - Ensures **graceful shutdown** by releasing the webcam and closing OpenCV windows.
#
# ---
#
# ### **🔹 Notes**
# - The **YOLO model should be trained** and tested before use.
# - The confidence threshold (`conf=0.8`) can be **adjusted** for better results.
# - The script runs **in real-time**, so performance depends on **hardware (CPU/GPU)**.
# - Bounding boxes and labels are drawn with **OpenCV (`cv2.rectangle()` & `cv2.putText()`)**.

# %%
import sqlite3

# Function to fetch product details by name
def get_product_details(product_name):
    conn = sqlite3.connect("products.db")
    cursor = conn.cursor()

    # Query database for the product
    cursor.execute("SELECT * FROM products WHERE name = ?", (product_name,))
    product = cursor.fetchone()

    conn.close()
    return product  # Returns None if no product is found

# %% [markdown]
# ### **🔹 Key Features**
# ✅ **Connects to a SQLite database (`products.db`)**.
# ✅ **Fetches product details based on the product name**.
# ✅ **Returns all stored product information (or `None` if not found)**.
#
# ---
#
# ### **🔹 How It Works**
#
# 1. **Establish a Database Connection (`sqlite3.connect()`)**
#    - Connects to **`products.db`**, which stores product details.
#    - Allows SQL queries to be executed on the database.
#
# 2. **Execute a SQL Query (`cursor.execute()`)**
#    - Runs a **parameterized query** (`?` placeholder) to prevent SQL injection.
#    - Searches for a product where the **name matches the input (`product_name`)**.
#
# 3. **Retrieve the Product Data (`cursor.fetchone()`)**
#    - Returns **the first matching row** as a tuple.
#    - If **no match is found**, it returns `None`.
#
# 4. **Close the Database Connection (`conn.close()`)**
#    - Ensures the database connection is properly **closed after the query**.
#
# ---
#
# ### **🔹 Notes**
# - The function assumes that the **product name is unique** in the database.
# - If multiple products have the same name, **only the first match** will be returned.
# - The function can be modified to return **all matches** using `cursor.fetchall()`.
# - The database file (`products.db`) **must exist** and contain the `products` table for this function to work correctly.

# %%
import database_queries  # Import function to fetch product details

# Load YOLOv8 model
model = YOLO("best.pt")  # Replace with your trained YOLOv8 model path

# Capture an image (or use a test image)
image_path = r"C:\Users\Adonis\OneDrive\Desktop\DataScience\Projects\MotionDetection\StreamLit\Images\Teriaq-Intense.jpeg"
image = cv2.imread(image_path)

# Run YOLO prediction
results = model(image)

# Ensure detections exist
if results and len(results[0].boxes) > 0:  
    # Get the class ID of the detected object
    detected_class_id = int(results[0].boxes.cls[0])  

    # Get the corresponding label name
    detected_label = model.names[detected_class_id]  

    print(f"Detected Product: {detected_label}")

    # Query database for product details
    product_info = database_queries.get_product_details(detected_label)

    if product_info:
        print("\nProduct Details Found:")
        print(f"ID: {product_info[0]}")
        print(f"Name: {product_info[1]}")
        print(f"Category: {product_info[2]}")
        print(f"Genre: {product_info[3]}")
        print(f"Price: ${product_info[4]}")
        print(f"Description: {product_info[5]}")
        print(f"Image Path: {product_info[6]}")
    else:
        print("\n❌ Product not found in database!")
else:
    print("\n❌ No product detected!")
# Out:
# 0: 640x544 1 Teriaq-Intense, 198.7ms
# Speed: 4.5ms preprocess, 198.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 544)
# Detected Product: Teriaq-Intense
#
# Product Details Found:
# ID: 1
# Name: Teriaq-Intense
# Category: Perfume
# Genre: Sweet
# Price: $180.0
# Description: A rich and captivating sweet fragrance with deep notes of vanilla and caramel, leaving a long-lasting impression.
# Image Path: C:\Users\Adonis\OneDrive\Desktop\DataScience\Projects\MotionDetection\StreamLit\Images\Teriaq-Intense.jpeg

# %% [markdown]
# ### **🔹 Key Features**
# ✅ **Loads a trained YOLOv8 model for object detection**.
# ✅ **Detects objects in a given image** using YOLOv8.
# ✅ **Extracts the detected object label and queries a SQLite database for details**.
# ✅ **Displays product details (ID, name, category, genre, price, description, and image path)**.
#
# ---
#
# ### **🔹 How It Works**
#
# 1. **Import the `database_queries` module**
#    - Loads the function `get_product_details()`, which fetches product details from the database.
#
# 2. **Load the YOLOv8 Model (`YOLO("best.pt")`)**
#    - Loads a **custom-trained YOLOv8 model** to detect objects.
#    - The model is stored in `best.pt`, which contains learned weights from training.
#
# 3. **Read the Image (`cv2.imread()`)**
#    - Loads an image from a specified path (`Teriaq-Intense.jpeg`).
#    - The image is used as input for YOLOv8 object detection.
#
# 4. **Run Object Detection (`model(image)`)**
#    - YOLO processes the image and detects objects.
#    - Returns **bounding boxes, class IDs, and confidence scores**.
#
# 5. **Extract the Detected Object's Class Label**
#    - **`boxes.cls[0]`** retrieves the **class index** of the detected object.
#    - **`model.names[class_id]`** maps the class index to a **human-readable label**.
#
# 6. **Query the Database (`database_queries.get_product_details()`)**
#    - Searches the `products.db` database for the detected product name.
#    - Returns product details if the product is found.
#
# 7. **Display Product Details**
#    - If the product exists in the database, prints:
#      - **ID, Name, Category, Genre, Price, Description, and Image Path**.
#    - If not found, displays: **"❌ Product not found in database!"**.
#
# 8. **Handle Cases When No Object is Detected**
#    - If YOLOv8 **detects nothing**, the script prints `"❌ No product detected!"`.
#    - Prevents crashes when no valid detection is made.
#
# ---
#
# ### **🔹 Notes**
# - The **YOLOv8 model (`best.pt`) should be trained** on the dataset containing product images.
# - Ensure the **image file exists at the given path** before running detection.
# - The **SQLite database (`products.db`) should contain relevant product information** for proper retrieval.
# - If detection is inaccurate, consider **lowering the confidence threshold** when running `model(image)`.

# %%
import sqlite3

conn = sqlite3.connect("products.db")
cursor = conn.cursor()

# Check database integrity
cursor.execute("PRAGMA integrity_check;")
result = cursor.fetchone()

print("Database Integrity Check:", result[0])

conn.close()
# Out:
# Database Integrity Check: ok

# %% [markdown]
# ### **🔹 Key Features**
# ✅ **Connects to the SQLite database (`products.db`)**.
# ✅ **Runs an integrity check to detect database corruption**.
# ✅ **Prints the status of the database (`ok` if no corruption is found)**.
# ✅ **Closes the database connection after the check**.
#
# ---
#
# ### **🔹 How It Works**
#
# 1. **Establish a Database Connection (`sqlite3.connect()`)**
#    - Opens a connection to the SQLite database **`products.db`**.
#    - Allows SQL commands to be executed on the database.
#
# 2. **Execute an Integrity Check (`PRAGMA integrity_check;`)**
#    - **PRAGMA integrity_check** is a built-in SQLite command that:
#      - Scans the database for corruption.
#      - Verifies that **all tables and indexes are properly structured**.
#      - Detects **missing or broken references**.
#
# 3. **Retrieve the Integrity Check Result (`cursor.fetchone()`)**
#    - Fetches the **output** of the integrity check:
#      - If **`ok`**, the database is healthy.
#      - If **an error message appears**, the database is corrupted.
#
# 4. **Print the Integrity Status**
#    - Displays the **status of the database** in the console.
#    - Helps diagnose **corruption issues before running queries**.
#
# 5. **Close the Database Connection (`conn.close()`)**
#    - Ensures the connection is **properly closed** after executing the check.
#
# ---
#
# ### **🔹 Notes**
# - If the **output is `"ok"`**, your database is **healthy and working properly**.
# - If the **output shows errors**, your database **may be corrupted** and needs to be repaired.
# - If corruption is detected, try **dumping the database using `.dump`** or **rebuilding it from a backup**.

# %%
import database_queries  # Import function to fetch product details
import os

# Load YOLOv8 model
model = YOLO("best.pt")  # Replace with your trained YOLOv8 model path

# Open the webcam (0 = default camera)
cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, frame = cap.read()  # Capture a frame from the webcam
    if not ret:
        break  # Exit if the frame is not captured properly

    # Run YOLO detection on the frame
    results = model(frame)

    # Ensure at least one object is detected
    if results and len(results[0].boxes) > 0:
        # Get the class ID of the detected object
        detected_class_id = int(results[0].boxes.cls[0])

        # Get the corresponding label name from YOLO's class names
        detected_label = model.names[detected_class_id]
        print(f"Detected Product: {detected_label}")

        # Query the database to get product details
        product_info = database_queries.get_product_details(detected_label)

        if product_info:
            # Extract product details from database
            product_id, name, category, genre, price, description, image_path = product_info

            # Display ALL product details as text overlay
            overlay_text = [
                f"ID: {product_id}",
                f"Name: {name}",
                f"Category: {category}",
                f"Genre: {genre}",
                f"Price: ${price}",
                f"Description: {description}",
            ]

            y_offset = 50  # Start position for text overlay
            for line in overlay_text:
                cv2.putText(frame, line, (50, y_offset), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
                y_offset += 25  # Move down for each line

            # Display product image if available
            if os.path.exists(image_path):
                img = cv2.imread(image_path)  # Read the product image
                img = cv2.resize(img, (150, 150))  # Resize to fit overlay area
                frame[50:200, 400:550] = img  # Overlay the image on the video feed
        else:
            # If product is not found in the database
            cv2.putText(frame, "Product not found!", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    # Display the real-time video feed with product details
    cv2.imshow("Product Recognition", frame)

    # Press 'q' to exit the program
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 66.7ms
# Speed: 4.0ms preprocess, 66.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 71.5ms
# Speed: 2.0ms preprocess, 71.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.4ms
# Speed: 3.0ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.5ms
# Speed: 2.8ms preprocess, 54.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.9ms
# Speed: 1.1ms preprocess, 54.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.1ms
# Speed: 1.7ms preprocess, 55.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.1ms
# Speed: 2.2ms preprocess, 52.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.8ms
# Speed: 1.0ms preprocess, 50.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.6ms
# Speed: 2.0ms preprocess, 54.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.2ms
# Speed: 1.1ms preprocess, 63.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.7ms
# Speed: 1.3ms preprocess, 54.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.8ms
# Speed: 1.0ms preprocess, 57.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 61.1ms
# Speed: 2.2ms preprocess, 61.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 59.8ms
# Speed: 2.0ms preprocess, 59.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 (no detections), 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 56.1ms
# Speed: 2.0ms preprocess, 56.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 83.0ms
# Speed: 2.5ms preprocess, 83.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 147.9ms
# Speed: 2.5ms preprocess, 147.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 78.6ms
# Speed: 1.0ms preprocess, 78.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 66.1ms
# Speed: 1.0ms preprocess, 66.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 58.2ms
# Speed: 2.1ms preprocess, 58.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 61.8ms
# Speed: 2.1ms preprocess, 61.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 87.1ms
# Speed: 2.1ms preprocess, 87.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 214.7ms
# Speed: 1.0ms preprocess, 214.7ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 64.7ms
# Speed: 1.0ms preprocess, 64.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 64.3ms
# Speed: 1.0ms preprocess, 64.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 60.3ms
# Speed: 2.5ms preprocess, 60.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 58.7ms
# Speed: 1.5ms preprocess, 58.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 60.9ms
# Speed: 1.2ms preprocess, 60.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 62.5ms
# Speed: 1.0ms preprocess, 62.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 (no detections), 57.7ms
# Speed: 2.4ms preprocess, 57.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 65.4ms
# Speed: 1.4ms preprocess, 65.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 61.7ms
# Speed: 0.9ms preprocess, 61.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 65.1ms
# Speed: 1.5ms preprocess, 65.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 70.7ms
# Speed: 2.0ms preprocess, 70.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 70.2ms
# Speed: 3.0ms preprocess, 70.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 67.8ms
# Speed: 2.5ms preprocess, 67.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 62.5ms
# Speed: 2.5ms preprocess, 62.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 64.1ms
# Speed: 2.5ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 132.8ms
# Speed: 1.2ms preprocess, 132.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 61.6ms
# Speed: 1.5ms preprocess, 61.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 60.3ms
# Speed: 1.0ms preprocess, 60.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 80.2ms
# Speed: 2.4ms preprocess, 80.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 87.4ms
# Speed: 2.0ms preprocess, 87.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 71.2ms
# Speed: 2.1ms preprocess, 71.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 69.8ms
# Speed: 2.0ms preprocess, 69.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 58.0ms
# Speed: 2.4ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 75.8ms
# Speed: 27.6ms preprocess, 75.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 59.9ms
# Speed: 2.0ms preprocess, 59.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 58.9ms
# Speed: 1.1ms preprocess, 58.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 59.3ms
# Speed: 2.0ms preprocess, 59.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 61.7ms
# Speed: 2.0ms preprocess, 61.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 54.7ms
# Speed: 1.3ms preprocess, 54.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 (no detections), 88.8ms
# Speed: 2.3ms preprocess, 88.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.3ms
# Speed: 2.0ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 64.6ms
# Speed: 2.2ms preprocess, 64.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.8ms
# Speed: 1.4ms preprocess, 58.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.9ms
# Speed: 1.0ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.0ms
# Speed: 1.0ms preprocess, 59.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.4ms
# Speed: 2.0ms preprocess, 53.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 58.0ms
# Speed: 0.9ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 54.9ms
# Speed: 1.0ms preprocess, 54.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 56.2ms
# Speed: 1.0ms preprocess, 56.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 58.1ms
# Speed: 1.0ms preprocess, 58.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 54.5ms
# Speed: 2.5ms preprocess, 54.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 68.5ms
# Speed: 1.5ms preprocess, 68.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 55.9ms
# Speed: 1.0ms preprocess, 55.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 66.6ms
# Speed: 1.0ms preprocess, 66.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 59.5ms
# Speed: 1.0ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 59.2ms
# Speed: 1.4ms preprocess, 59.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 54.7ms
# Speed: 1.1ms preprocess, 54.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 59.0ms
# Speed: 1.0ms preprocess, 59.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 59.0ms
# Speed: 2.2ms preprocess, 59.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 67.1ms
# Speed: 1.0ms preprocess, 67.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 (no detections), 67.5ms
# Speed: 1.0ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.4ms
# Speed: 1.0ms preprocess, 60.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.9ms
# Speed: 2.0ms preprocess, 63.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 62.9ms
# Speed: 2.2ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 57.5ms
# Speed: 2.3ms preprocess, 57.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 60.6ms
# Speed: 2.0ms preprocess, 60.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 62.6ms
# Speed: 1.0ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 59.6ms
# Speed: 1.5ms preprocess, 59.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 58.1ms
# Speed: 3.1ms preprocess, 58.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 62.4ms
# Speed: 2.0ms preprocess, 62.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 85.9ms
# Speed: 1.4ms preprocess, 85.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 59.8ms
# Speed: 2.1ms preprocess, 59.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 54.8ms
# Speed: 2.5ms preprocess, 54.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 52.9ms
# Speed: 2.2ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 60.6ms
# Speed: 1.0ms preprocess, 60.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 55.3ms
# Speed: 2.2ms preprocess, 55.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 58.3ms
# Speed: 2.2ms preprocess, 58.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 55.3ms
# Speed: 2.0ms preprocess, 55.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 63.7ms
# Speed: 2.0ms preprocess, 63.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 68.9ms
# Speed: 2.0ms preprocess, 68.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 56.7ms
# Speed: 2.1ms preprocess, 56.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 60.2ms
# Speed: 1.0ms preprocess, 60.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 57.9ms
# Speed: 2.4ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 56.4ms
# Speed: 1.0ms preprocess, 56.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 52.5ms
# Speed: 1.2ms preprocess, 52.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 58.4ms
# Speed: 2.0ms preprocess, 58.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 56.6ms
# Speed: 1.0ms preprocess, 56.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 54.4ms
# Speed: 1.5ms preprocess, 54.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 55.5ms
# Speed: 1.5ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 56.1ms
# Speed: 1.0ms preprocess, 56.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 55.2ms
# Speed: 1.1ms preprocess, 55.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 60.6ms
# Speed: 1.0ms preprocess, 60.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 55.6ms
# Speed: 1.0ms preprocess, 55.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 54.9ms
# Speed: 1.9ms preprocess, 54.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 58.9ms
# Speed: 2.4ms preprocess, 58.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 57.9ms
# Speed: 1.0ms preprocess, 57.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 56.0ms
# Speed: 2.5ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 56.6ms
# Speed: 1.0ms preprocess, 56.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 54.6ms
# Speed: 1.4ms preprocess, 54.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 56.6ms
# Speed: 2.5ms preprocess, 56.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 59.7ms
# Speed: 1.0ms preprocess, 59.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 79.3ms
# Speed: 3.0ms preprocess, 79.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 55.4ms
# Speed: 2.2ms preprocess, 55.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 55.5ms
# Speed: 1.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 69.9ms
# Speed: 2.5ms preprocess, 69.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 56.3ms
# Speed: 2.0ms preprocess, 56.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 57.9ms
# Speed: 1.0ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 58.0ms
# Speed: 1.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 55.4ms
# Speed: 1.4ms preprocess, 55.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 51.8ms
# Speed: 1.2ms preprocess, 51.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 53.8ms
# Speed: 2.1ms preprocess, 53.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 57.7ms
# Speed: 1.0ms preprocess, 57.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 56.4ms
# Speed: 1.5ms preprocess, 56.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 56.1ms
# Speed: 1.0ms preprocess, 56.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 55.9ms
# Speed: 1.0ms preprocess, 55.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 55.1ms
# Speed: 3.1ms preprocess, 55.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 1 Teriaq-Intense, 59.9ms
# Speed: 2.4ms preprocess, 59.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 1 Teriaq-Intense, 55.4ms
# Speed: 1.0ms preprocess, 55.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 1 Teriaq-Intense, 57.8ms
# Speed: 2.0ms preprocess, 57.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 1 Teriaq-Intense, 60.9ms
# Speed: 1.0ms preprocess, 60.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 1 Teriaq-Intense, 52.5ms
# Speed: 1.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 1 Teriaq-Intense, 52.3ms
# Speed: 2.0ms preprocess, 52.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 1 Teriaq-Intense, 50.2ms
# Speed: 1.0ms preprocess, 50.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 1 Teriaq-Intense, 54.2ms
# Speed: 1.0ms preprocess, 54.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 1 Teriaq-Intense, 52.2ms
# Speed: 1.2ms preprocess, 52.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 49.1ms
# Speed: 1.0ms preprocess, 49.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 52.5ms
# Speed: 1.1ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 51.9ms
# Speed: 1.8ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 63.5ms
# Speed: 1.0ms preprocess, 63.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 58.6ms
# Speed: 1.0ms preprocess, 58.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 51.6ms
# Speed: 1.0ms preprocess, 51.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 1 Teriaq-Intense, 50.2ms
# Speed: 1.0ms preprocess, 50.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 50.4ms
# Speed: 2.4ms preprocess, 50.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 51.2ms
# Speed: 2.5ms preprocess, 51.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 49.7ms
# Speed: 1.0ms preprocess, 49.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 49.7ms
# Speed: 1.5ms preprocess, 49.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 52.3ms
# Speed: 2.0ms preprocess, 52.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 54.6ms
# Speed: 1.0ms preprocess, 54.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 2 Teriaq-Intenses, 52.6ms
# Speed: 1.0ms preprocess, 52.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 2 Teriaq-Intenses, 80.1ms
# Speed: 0.0ms preprocess, 80.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 52.9ms
# Speed: 1.0ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 51.0ms
# Speed: 1.5ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 52.6ms
# Speed: 1.0ms preprocess, 52.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 51.0ms
# Speed: 1.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 50.5ms
# Speed: 1.4ms preprocess, 50.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 49.9ms
# Speed: 1.0ms preprocess, 49.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 49.4ms
# Speed: 1.0ms preprocess, 49.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 2 Teriaq-Intenses, 52.8ms
# Speed: 0.0ms preprocess, 52.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 2 Teriaq-Intenses, 50.7ms
# Speed: 1.1ms preprocess, 50.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 52.5ms
# Speed: 0.5ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 50.3ms
# Speed: 1.5ms preprocess, 50.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 53.1ms
# Speed: 1.6ms preprocess, 53.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 52.7ms
# Speed: 2.0ms preprocess, 52.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 54.0ms
# Speed: 1.5ms preprocess, 54.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 50.0ms
# Speed: 1.4ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 53.9ms
# Speed: 2.0ms preprocess, 53.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 51.8ms
# Speed: 1.0ms preprocess, 51.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 93.5ms
# Speed: 1.0ms preprocess, 93.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 53.8ms
# Speed: 1.0ms preprocess, 53.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 51.4ms
# Speed: 1.0ms preprocess, 51.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 50.7ms
# Speed: 1.4ms preprocess, 50.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 53.1ms
# Speed: 1.2ms preprocess, 53.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 50.5ms
# Speed: 1.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 54.7ms
# Speed: 1.5ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 53.7ms
# Speed: 1.0ms preprocess, 53.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 49.7ms
# Speed: 1.0ms preprocess, 49.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 50.6ms
# Speed: 1.4ms preprocess, 50.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 53.0ms
# Speed: 1.5ms preprocess, 53.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 49.4ms
# Speed: 1.5ms preprocess, 49.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 62.8ms
# Speed: 1.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 55.9ms
# Speed: 2.0ms preprocess, 55.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 62.6ms
# Speed: 1.5ms preprocess, 62.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Teriaq-Intense, 50.2ms
# Speed: 2.0ms preprocess, 50.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 52.3ms
# Speed: 0.9ms preprocess, 52.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 51.6ms
# Speed: 1.0ms preprocess, 51.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 52.2ms
# Speed: 1.0ms preprocess, 52.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Teriaq-Intense
#
# 0: 480x640 2 Afnans, 1 Teriaq-Intense, 51.1ms
# Speed: 1.0ms preprocess, 51.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 1 Teriaq-Intense, 53.3ms
# Speed: 1.2ms preprocess, 53.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 1 Teriaq-Intense, 56.3ms
# Speed: 2.5ms preprocess, 56.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 1 Teriaq-Intense, 56.5ms
# Speed: 1.0ms preprocess, 56.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 1 Teriaq-Intense, 59.1ms
# Speed: 1.3ms preprocess, 59.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 1 Teriaq-Intense, 60.4ms
# Speed: 1.0ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 1 Teriaq-Intense, 85.3ms
# Speed: 2.3ms preprocess, 85.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 1 Teriaq-Intense, 58.4ms
# Speed: 1.5ms preprocess, 58.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 1 Teriaq-Intense, 55.3ms
# Speed: 2.0ms preprocess, 55.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 57.6ms
# Speed: 1.0ms preprocess, 57.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 51.2ms
# Speed: 1.0ms preprocess, 51.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 (no detections), 50.7ms
# Speed: 1.0ms preprocess, 50.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.2ms
# Speed: 1.6ms preprocess, 53.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 51.9ms
# Speed: 2.5ms preprocess, 51.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 (no detections), 52.9ms
# Speed: 1.4ms preprocess, 52.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.4ms
# Speed: 1.0ms preprocess, 51.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.0ms
# Speed: 1.5ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.6ms
# Speed: 1.1ms preprocess, 53.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 86.7ms
# Speed: 1.1ms preprocess, 86.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 (no detections), 51.8ms
# Speed: 3.0ms preprocess, 51.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.4ms
# Speed: 1.0ms preprocess, 54.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.6ms
# Speed: 2.3ms preprocess, 51.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.1ms
# Speed: 3.0ms preprocess, 53.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.2ms
# Speed: 2.2ms preprocess, 54.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.5ms
# Speed: 1.5ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.3ms
# Speed: 1.5ms preprocess, 50.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.4ms
# Speed: 1.3ms preprocess, 51.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.4ms
# Speed: 2.0ms preprocess, 52.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.3ms
# Speed: 1.5ms preprocess, 51.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.2ms
# Speed: 2.1ms preprocess, 51.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 49.9ms
# Speed: 2.5ms preprocess, 49.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 51.5ms
# Speed: 2.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 81.4ms
# Speed: 1.0ms preprocess, 81.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 55.8ms
# Speed: 1.0ms preprocess, 55.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 57.6ms
# Speed: 1.6ms preprocess, 57.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 60.3ms
# Speed: 1.0ms preprocess, 60.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 2 Afnans, 60.2ms
# Speed: 2.0ms preprocess, 60.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 56.8ms
# Speed: 0.9ms preprocess, 56.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan
#
# 0: 480x640 1 Afnan, 61.3ms
# Speed: 1.1ms preprocess, 61.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected Product: Afnan

# %% [markdown]
# ---
#
# ### **📄 File: `real_time_detection.py`**
#
# ### **🔹 How This Works**
# 1. **Captures live video from the webcam**.
# 2. **Runs YOLOv8 object detection** on each frame.
# 3. **Extracts the detected product label** from YOLO’s predictions.
# 4. **Searches for the product in the SQLite database**.
# 5. **Displays product details** (name, price, description) as an overlay on the video feed.
# 6. **Displays product image** (if found) on the right side of the frame.
# 7. **Press 'q' to exit** the live detection.
#
#
#
#
# ---
#
# ### **💡 Next Steps**
# ✅ **Want to integrate it into a Streamlit web app?** 🖥
# ✅ **Need help training YOLOv8 on your custom product dataset?** 📦
# ✅ **Want to add voice-based product info (text-to-speech)?** 🔊

# %%
import cv2
import mediapipe as mp
import numpy as np
from ultralytics import YOLO
import database_queries
import os
from collections import deque, Counter

# Initialize MediaPipe drawing utilities
mp_draw = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# Load YOLOv8 model
model = YOLO("best.pt")

# Gesture smoothing buffer
GESTURE_HISTORY_SIZE = 10
gesture_history = deque(maxlen=GESTURE_HISTORY_SIZE)

# Start video capture
cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.flip(frame, 1)
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = hands.process(rgb_frame)  # Use imported 'hands' model

    current_gesture = "No Hand"
    
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            # Draw hand landmarks and connections
            mp_draw.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS,
                                   mp_draw.DrawingSpec(color=(0, 255, 0), thickness=2, circle_radius=4),
                                   mp_draw.DrawingSpec(color=(0, 0, 255), thickness=2))

            current_gesture = detect_gesture(hand_landmarks)  # Detect gesture using existing function

    gesture_history.append(current_gesture)
    most_common_gesture = Counter(gesture_history).most_common(1)[0][0]

    # Display detected gesture
    cv2.putText(frame, f"Gesture: {most_common_gesture}", (50, 50),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # Run YOLO only if "Pointing" or "Holding"
    if most_common_gesture in ["Pointing", "Holding"]:
        results = model.predict(frame, conf=0.7)
        if results and len(results[0].boxes) > 0:
            for box in results[0].boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                cls_id, conf = int(box.cls[0]), float(box.conf[0])
                detected_label = model.names[cls_id]

                # Fetch product details
                product_info = database_queries.get_product_details(detected_label)

                if product_info:
                    product_id, name, category, genre, price, description, image_path = product_info
                    details = [f"ID: {product_id}", f"Name: {name}", f"Category: {category}",
                               f"Genre: {genre}", f"Price: ${price}", f"Desc: {description}"]
                    y_offset = 80
                    for detail in details:
                        cv2.putText(frame, detail, (50, y_offset),
                                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
                        y_offset += 25

                    # Display product image
                    if os.path.exists(image_path):
                        img = cv2.imread(image_path)
                        img = cv2.resize(img, (150, 150))
                        frame[50:200, 400:550] = img
                else:
                    cv2.putText(frame, "Product not found!", (50, 80),
                                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    # Show the video
    cv2.imshow("Gesture-Based Product Recognition", frame)

    # Exit when 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 51.7ms
# Speed: 1.0ms preprocess, 51.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.5ms
# Speed: 0.5ms preprocess, 56.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.5ms
# Speed: 1.0ms preprocess, 52.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 54.4ms
# Speed: 1.0ms preprocess, 54.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 59.2ms
# Speed: 1.5ms preprocess, 59.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 58.3ms
# Speed: 1.0ms preprocess, 58.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 55.6ms
# Speed: 1.0ms preprocess, 55.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 57.7ms
# Speed: 1.1ms preprocess, 57.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 62.9ms
# Speed: 2.9ms preprocess, 62.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 47.5ms
# Speed: 1.1ms preprocess, 47.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 47.5ms
# Speed: 2.2ms preprocess, 47.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 48.6ms
# Speed: 2.3ms preprocess, 48.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 48.2ms
# Speed: 1.0ms preprocess, 48.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 51.1ms
# Speed: 1.0ms preprocess, 51.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 47.9ms
# Speed: 2.0ms preprocess, 47.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 49.2ms
# Speed: 1.0ms preprocess, 49.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 48.9ms
# Speed: 2.0ms preprocess, 48.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 49.2ms
# Speed: 1.4ms preprocess, 49.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 50.0ms
# Speed: 1.5ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 62.5ms
# Speed: 1.5ms preprocess, 62.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.5ms
# Speed: 1.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.9ms
# Speed: 0.0ms preprocess, 50.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 47.9ms
# Speed: 0.9ms preprocess, 47.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.9ms
# Speed: 1.0ms preprocess, 52.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.6ms
# Speed: 1.4ms preprocess, 50.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 48.7ms
# Speed: 2.1ms preprocess, 48.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.0ms
# Speed: 1.4ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 49.7ms
# Speed: 1.0ms preprocess, 49.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.6ms
# Speed: 1.0ms preprocess, 53.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.7ms
# Speed: 1.0ms preprocess, 51.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.8ms
# Speed: 1.6ms preprocess, 51.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.2ms
# Speed: 1.2ms preprocess, 52.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.4ms
# Speed: 1.1ms preprocess, 52.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.5ms
# Speed: 0.0ms preprocess, 51.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 72.9ms
# Speed: 1.0ms preprocess, 72.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 61.2ms
# Speed: 1.5ms preprocess, 61.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 53.5ms
# Speed: 1.0ms preprocess, 53.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.4ms
# Speed: 1.0ms preprocess, 52.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.7ms
# Speed: 1.5ms preprocess, 50.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.2ms
# Speed: 0.6ms preprocess, 52.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 54.1ms
# Speed: 1.7ms preprocess, 54.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 55.8ms
# Speed: 1.0ms preprocess, 55.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 54.8ms
# Speed: 1.0ms preprocess, 54.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 55.9ms
# Speed: 1.0ms preprocess, 55.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 53.6ms
# Speed: 1.5ms preprocess, 53.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.2ms
# Speed: 1.0ms preprocess, 52.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.1ms
# Speed: 2.5ms preprocess, 52.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 56.4ms
# Speed: 1.0ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 56.4ms
# Speed: 2.1ms preprocess, 56.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 57.2ms
# Speed: 1.0ms preprocess, 57.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 53.1ms
# Speed: 2.0ms preprocess, 53.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 55.7ms
# Speed: 1.0ms preprocess, 55.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 55.4ms
# Speed: 1.0ms preprocess, 55.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 56.1ms
# Speed: 2.2ms preprocess, 56.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 62.5ms
# Speed: 1.0ms preprocess, 62.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.4ms
# Speed: 0.6ms preprocess, 51.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 53.9ms
# Speed: 2.0ms preprocess, 53.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.3ms
# Speed: 1.2ms preprocess, 52.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 49.3ms
# Speed: 1.0ms preprocess, 49.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.3ms
# Speed: 1.0ms preprocess, 52.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.5ms
# Speed: 1.5ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 53.1ms
# Speed: 1.0ms preprocess, 53.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 53.1ms
# Speed: 1.5ms preprocess, 53.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.0ms
# Speed: 2.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.6ms
# Speed: 1.0ms preprocess, 51.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.3ms
# Speed: 1.9ms preprocess, 50.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.8ms
# Speed: 1.0ms preprocess, 50.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 107.6ms
# Speed: 1.0ms preprocess, 107.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.8ms
# Speed: 1.0ms preprocess, 51.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.3ms
# Speed: 2.0ms preprocess, 52.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 51.4ms
# Speed: 1.0ms preprocess, 51.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 50.5ms
# Speed: 2.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 50.5ms
# Speed: 1.0ms preprocess, 50.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 50.7ms
# Speed: 2.0ms preprocess, 50.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 51.3ms
# Speed: 1.0ms preprocess, 51.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 64.7ms
# Speed: 0.5ms preprocess, 64.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 51.4ms
# Speed: 1.0ms preprocess, 51.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 49.1ms
# Speed: 2.3ms preprocess, 49.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 50.6ms
# Speed: 1.0ms preprocess, 50.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 49.8ms
# Speed: 1.1ms preprocess, 49.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 50.8ms
# Speed: 1.0ms preprocess, 50.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 51.3ms
# Speed: 1.4ms preprocess, 51.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 50.0ms
# Speed: 1.1ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Afnans, 51.3ms
# Speed: 0.0ms preprocess, 51.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 52.5ms
# Speed: 1.0ms preprocess, 52.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 55.0ms
# Speed: 2.2ms preprocess, 55.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 50.1ms
# Speed: 1.3ms preprocess, 50.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 52.9ms
# Speed: 1.5ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 53.4ms
# Speed: 1.3ms preprocess, 53.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.8ms
# Speed: 1.0ms preprocess, 51.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.2ms
# Speed: 1.4ms preprocess, 51.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 49.5ms
# Speed: 1.3ms preprocess, 49.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.0ms
# Speed: 1.0ms preprocess, 51.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.8ms
# Speed: 1.0ms preprocess, 51.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.0ms
# Speed: 1.5ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.9ms
# Speed: 1.5ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 67.7ms
# Speed: 1.0ms preprocess, 67.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 48.5ms
# Speed: 1.0ms preprocess, 48.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 58.9ms
# Speed: 2.4ms preprocess, 58.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 52.7ms
# Speed: 2.5ms preprocess, 52.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 56.5ms
# Speed: 1.4ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 57.0ms
# Speed: 1.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 59.3ms
# Speed: 3.2ms preprocess, 59.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 56.1ms
# Speed: 1.0ms preprocess, 56.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 52.6ms
# Speed: 1.5ms preprocess, 52.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 53.3ms
# Speed: 1.9ms preprocess, 53.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 55.4ms
# Speed: 1.5ms preprocess, 55.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 53.8ms
# Speed: 1.6ms preprocess, 53.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 57.4ms
# Speed: 2.3ms preprocess, 57.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 52.1ms
# Speed: 1.5ms preprocess, 52.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 52.5ms
# Speed: 2.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 54.5ms
# Speed: 2.5ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 79.8ms
# Speed: 1.0ms preprocess, 79.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 59.4ms
# Speed: 2.0ms preprocess, 59.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 60.5ms
# Speed: 1.0ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 62.5ms
# Speed: 1.0ms preprocess, 62.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.9ms
# Speed: 1.9ms preprocess, 54.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 57.1ms
# Speed: 1.0ms preprocess, 57.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.4ms
# Speed: 1.0ms preprocess, 58.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.9ms
# Speed: 2.0ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 54.3ms
# Speed: 1.5ms preprocess, 54.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 53.7ms
# Speed: 1.5ms preprocess, 53.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 68.1ms
# Speed: 1.0ms preprocess, 68.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 54.8ms
# Speed: 2.0ms preprocess, 54.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.8ms
# Speed: 2.0ms preprocess, 54.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 54.4ms
# Speed: 1.5ms preprocess, 54.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 53.1ms
# Speed: 1.0ms preprocess, 53.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.9ms
# Speed: 2.0ms preprocess, 52.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 54.8ms
# Speed: 0.9ms preprocess, 54.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.2ms
# Speed: 1.0ms preprocess, 55.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.0ms
# Speed: 1.0ms preprocess, 52.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 66.4ms
# Speed: 2.0ms preprocess, 66.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.8ms
# Speed: 0.0ms preprocess, 51.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 73.3ms
# Speed: 1.5ms preprocess, 73.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.1ms
# Speed: 1.0ms preprocess, 51.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.9ms
# Speed: 1.5ms preprocess, 52.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 48.2ms
# Speed: 1.5ms preprocess, 48.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.2ms
# Speed: 1.5ms preprocess, 50.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.0ms
# Speed: 1.0ms preprocess, 52.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.4ms
# Speed: 2.5ms preprocess, 51.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.7ms
# Speed: 1.3ms preprocess, 51.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.4ms
# Speed: 0.0ms preprocess, 50.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.5ms
# Speed: 1.5ms preprocess, 50.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 49.8ms
# Speed: 1.0ms preprocess, 49.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.6ms
# Speed: 1.4ms preprocess, 52.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.0ms
# Speed: 1.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.4ms
# Speed: 2.5ms preprocess, 51.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.7ms
# Speed: 2.0ms preprocess, 52.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.8ms
# Speed: 1.0ms preprocess, 52.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.4ms
# Speed: 1.0ms preprocess, 52.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 57.5ms
# Speed: 1.0ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 49.2ms
# Speed: 1.0ms preprocess, 49.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.1ms
# Speed: 2.0ms preprocess, 50.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.3ms
# Speed: 1.0ms preprocess, 52.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 48.6ms
# Speed: 1.0ms preprocess, 48.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.4ms
# Speed: 1.2ms preprocess, 51.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.9ms
# Speed: 1.5ms preprocess, 51.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.0ms
# Speed: 1.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 63.2ms
# Speed: 1.0ms preprocess, 63.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.2ms
# Speed: 1.1ms preprocess, 51.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 48.4ms
# Speed: 1.0ms preprocess, 48.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 47.9ms
# Speed: 2.0ms preprocess, 47.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.2ms
# Speed: 1.0ms preprocess, 51.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.4ms
# Speed: 1.0ms preprocess, 50.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 49.7ms
# Speed: 1.0ms preprocess, 49.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.3ms
# Speed: 1.1ms preprocess, 51.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.6ms
# Speed: 1.0ms preprocess, 50.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.0ms
# Speed: 1.5ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 48.5ms
# Speed: 1.0ms preprocess, 48.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 53.2ms
# Speed: 1.0ms preprocess, 53.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 64.2ms
# Speed: 1.9ms preprocess, 64.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.8ms
# Speed: 2.0ms preprocess, 55.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.6ms
# Speed: 1.3ms preprocess, 52.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.5ms
# Speed: 1.4ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.3ms
# Speed: 1.9ms preprocess, 54.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 53.4ms
# Speed: 2.0ms preprocess, 53.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 62.9ms
# Speed: 2.6ms preprocess, 62.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 52.4ms
# Speed: 2.0ms preprocess, 52.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 55.2ms
# Speed: 1.0ms preprocess, 55.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 52.5ms
# Speed: 1.4ms preprocess, 52.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 50.1ms
# Speed: 1.0ms preprocess, 50.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 53.3ms
# Speed: 2.2ms preprocess, 53.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 51.0ms
# Speed: 1.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 53.7ms
# Speed: 1.0ms preprocess, 53.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 51.2ms
# Speed: 0.0ms preprocess, 51.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 53.4ms
# Speed: 1.0ms preprocess, 53.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 53.2ms
# Speed: 1.5ms preprocess, 53.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 52.9ms
# Speed: 1.5ms preprocess, 52.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 48.9ms
# Speed: 2.0ms preprocess, 48.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 52.8ms
# Speed: 1.0ms preprocess, 52.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 55.0ms
# Speed: 1.2ms preprocess, 55.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 51.9ms
# Speed: 2.0ms preprocess, 51.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 50.1ms
# Speed: 2.9ms preprocess, 50.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 52.0ms
# Speed: 2.1ms preprocess, 52.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 49.3ms
# Speed: 2.1ms preprocess, 49.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 50.8ms
# Speed: 0.5ms preprocess, 50.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 52.8ms
# Speed: 1.1ms preprocess, 52.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 51.2ms
# Speed: 1.8ms preprocess, 51.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 49.4ms
# Speed: 2.1ms preprocess, 49.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 52.4ms
# Speed: 1.1ms preprocess, 52.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 52.0ms
# Speed: 1.4ms preprocess, 52.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 55.3ms
# Speed: 2.0ms preprocess, 55.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 56.6ms
# Speed: 1.0ms preprocess, 56.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 69.9ms
# Speed: 2.0ms preprocess, 69.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 54.0ms
# Speed: 1.5ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 59.6ms
# Speed: 2.3ms preprocess, 59.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.6ms
# Speed: 1.0ms preprocess, 51.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 53.8ms
# Speed: 1.0ms preprocess, 53.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 57.3ms
# Speed: 1.5ms preprocess, 57.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.4ms
# Speed: 1.0ms preprocess, 52.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 55.8ms
# Speed: 2.3ms preprocess, 55.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 49.4ms
# Speed: 1.3ms preprocess, 49.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.9ms
# Speed: 1.5ms preprocess, 50.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.2ms
# Speed: 1.0ms preprocess, 51.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 49.3ms
# Speed: 1.0ms preprocess, 49.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.8ms
# Speed: 0.8ms preprocess, 52.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 49.3ms
# Speed: 3.0ms preprocess, 49.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.2ms
# Speed: 2.0ms preprocess, 52.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 51.8ms
# Speed: 1.5ms preprocess, 51.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 48.4ms
# Speed: 2.3ms preprocess, 48.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 51.4ms
# Speed: 2.0ms preprocess, 51.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 50.9ms
# Speed: 2.0ms preprocess, 50.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 53.2ms
# Speed: 1.9ms preprocess, 53.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 61.7ms
# Speed: 1.5ms preprocess, 61.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.3ms
# Speed: 1.0ms preprocess, 52.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.8ms
# Speed: 1.4ms preprocess, 52.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 52.2ms
# Speed: 1.0ms preprocess, 52.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 53.5ms
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 51.2ms
# Speed: 1.0ms preprocess, 51.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 51.5ms
# Speed: 2.0ms preprocess, 51.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 50.5ms
# Speed: 1.1ms preprocess, 50.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 50.0ms
# Speed: 2.3ms preprocess, 50.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 51.5ms
# Speed: 2.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 50.9ms
# Speed: 1.0ms preprocess, 50.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 48.2ms
# Speed: 1.7ms preprocess, 48.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.8ms
# Speed: 1.3ms preprocess, 50.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 52.1ms
# Speed: 2.0ms preprocess, 52.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 49.9ms
# Speed: 1.5ms preprocess, 49.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.7ms
# Speed: 1.1ms preprocess, 51.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 53.1ms
# Speed: 1.0ms preprocess, 53.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.6ms
# Speed: 1.6ms preprocess, 52.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 52.3ms
# Speed: 1.0ms preprocess, 52.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 50.8ms
# Speed: 2.1ms preprocess, 50.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.4ms
# Speed: 1.0ms preprocess, 51.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 53.2ms
# Speed: 1.0ms preprocess, 53.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.2ms
# Speed: 2.0ms preprocess, 52.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.1ms
# Speed: 2.6ms preprocess, 50.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 52.8ms
# Speed: 1.2ms preprocess, 52.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 49.3ms
# Speed: 1.5ms preprocess, 49.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 53.0ms
# Speed: 1.0ms preprocess, 53.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 49.7ms
# Speed: 2.0ms preprocess, 49.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 50.1ms
# Speed: 1.0ms preprocess, 50.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 51.0ms
# Speed: 1.1ms preprocess, 51.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 52.1ms
# Speed: 1.0ms preprocess, 52.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 53.8ms
# Speed: 2.0ms preprocess, 53.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 50.7ms
# Speed: 1.5ms preprocess, 50.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 50.4ms
# Speed: 2.0ms preprocess, 50.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 50.1ms
# Speed: 1.6ms preprocess, 50.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 49.3ms
# Speed: 1.2ms preprocess, 49.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 53.7ms
# Speed: 2.0ms preprocess, 53.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 48.7ms
# Speed: 1.6ms preprocess, 48.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 52.3ms
# Speed: 1.0ms preprocess, 52.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.8ms
# Speed: 2.0ms preprocess, 50.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.7ms
# Speed: 0.5ms preprocess, 50.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 50.6ms
# Speed: 0.0ms preprocess, 50.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 1 Teriaq-Intense, 50.5ms
# Speed: 1.5ms preprocess, 50.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.3ms
# Speed: 1.5ms preprocess, 51.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.6ms
# Speed: 1.0ms preprocess, 52.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 49.6ms
# Speed: 1.0ms preprocess, 49.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 49.2ms
# Speed: 1.0ms preprocess, 49.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.0ms
# Speed: 2.5ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 53.5ms
# Speed: 1.2ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.9ms
# Speed: 0.5ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.5ms
# Speed: 1.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 49.9ms
# Speed: 1.5ms preprocess, 49.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.9ms
# Speed: 1.5ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.2ms
# Speed: 2.1ms preprocess, 50.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 49.3ms
# Speed: 1.0ms preprocess, 49.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 55.3ms
# Speed: 2.0ms preprocess, 55.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 54.6ms
# Speed: 2.0ms preprocess, 54.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 56.5ms
# Speed: 1.5ms preprocess, 56.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 53.2ms
# Speed: 1.0ms preprocess, 53.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 54.1ms
# Speed: 2.0ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 57.8ms
# Speed: 1.0ms preprocess, 57.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.5ms
# Speed: 1.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.3ms
# Speed: 1.0ms preprocess, 51.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.9ms
# Speed: 2.0ms preprocess, 50.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 56.7ms
# Speed: 1.2ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 56.8ms
# Speed: 1.0ms preprocess, 56.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 56.3ms
# Speed: 1.0ms preprocess, 56.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 54.5ms
# Speed: 1.8ms preprocess, 54.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 69.7ms
# Speed: 1.5ms preprocess, 69.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.9ms
# Speed: 2.8ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 55.2ms
# Speed: 1.5ms preprocess, 55.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.9ms
# Speed: 1.5ms preprocess, 52.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 58.1ms
# Speed: 1.1ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 73.9ms
# Speed: 1.3ms preprocess, 73.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 53.2ms
# Speed: 0.0ms preprocess, 53.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.2ms
# Speed: 1.0ms preprocess, 50.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 53.8ms
# Speed: 1.3ms preprocess, 53.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 49.0ms
# Speed: 2.0ms preprocess, 49.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.7ms
# Speed: 2.0ms preprocess, 50.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.9ms
# Speed: 0.8ms preprocess, 50.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.2ms
# Speed: 1.5ms preprocess, 51.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.3ms
# Speed: 1.5ms preprocess, 52.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.8ms
# Speed: 2.0ms preprocess, 50.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 65.2ms
# Speed: 1.0ms preprocess, 65.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 49.1ms
# Speed: 1.0ms preprocess, 49.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 53.1ms
# Speed: 1.0ms preprocess, 53.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 53.5ms
# Speed: 1.3ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.5ms
# Speed: 2.0ms preprocess, 50.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.6ms
# Speed: 1.5ms preprocess, 51.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 60.9ms
# Speed: 1.5ms preprocess, 60.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.4ms
# Speed: 1.0ms preprocess, 50.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.1ms
# Speed: 1.8ms preprocess, 50.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 49.6ms
# Speed: 1.0ms preprocess, 49.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 50.3ms
# Speed: 1.5ms preprocess, 50.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 78.8ms
# Speed: 2.0ms preprocess, 78.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 48.3ms
# Speed: 1.5ms preprocess, 48.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 49.4ms
# Speed: 2.0ms preprocess, 49.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.4ms
# Speed: 0.0ms preprocess, 52.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.2ms
# Speed: 1.3ms preprocess, 52.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Afnans, 48.5ms
# Speed: 1.1ms preprocess, 48.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 52.2ms
# Speed: 1.3ms preprocess, 52.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 51.4ms
# Speed: 2.4ms preprocess, 51.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 49.6ms
# Speed: 2.0ms preprocess, 49.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 52.1ms
# Speed: 1.1ms preprocess, 52.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 50.4ms
# Speed: 1.0ms preprocess, 50.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 48.5ms
# Speed: 1.0ms preprocess, 48.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 50.9ms
# Speed: 1.0ms preprocess, 50.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 50.6ms
# Speed: 1.0ms preprocess, 50.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 49.1ms
# Speed: 1.0ms preprocess, 49.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.2ms
# Speed: 1.8ms preprocess, 52.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.8ms
# Speed: 1.4ms preprocess, 50.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 49.6ms
# Speed: 2.2ms preprocess, 49.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.2ms
# Speed: 1.0ms preprocess, 51.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.5ms
# Speed: 2.5ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 53.2ms
# Speed: 1.2ms preprocess, 53.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 51.1ms
# Speed: 1.2ms preprocess, 51.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 57.5ms
# Speed: 2.1ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Afnans, 54.8ms
# Speed: 1.5ms preprocess, 54.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 51.7ms
# Speed: 1.5ms preprocess, 51.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 52.2ms
# Speed: 1.2ms preprocess, 52.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 57.8ms
# ...
#
# 0: 480x640 1 Afnan, 54.3ms
# Speed: 1.9ms preprocess, 54.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 55.6ms
# Speed: 1.0ms preprocess, 55.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 57.0ms
# Speed: 1.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 53.5ms
# Speed: 1.5ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Afnans, 52.8ms
# Speed: 1.0ms preprocess, 52.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 56.9ms
# Speed: 2.0ms preprocess, 56.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 54.1ms
# Speed: 2.0ms preprocess, 54.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 56.1ms
# Speed: 1.5ms preprocess, 56.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 58.5ms
# Speed: 4.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.5ms
# Speed: 1.0ms preprocess, 58.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.4ms
# Speed: 1.5ms preprocess, 53.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.8ms
# Speed: 1.6ms preprocess, 55.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.6ms
# Speed: 2.0ms preprocess, 58.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.4ms
# Speed: 2.0ms preprocess, 59.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Afnans, 71.4ms
# Speed: 1.5ms preprocess, 71.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 68.9ms
# Speed: 2.0ms preprocess, 68.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 80.6ms
# Speed: 3.5ms preprocess, 80.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 64.6ms
# Speed: 2.0ms preprocess, 64.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.9ms
# Speed: 2.1ms preprocess, 53.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.3ms
# Speed: 1.1ms preprocess, 61.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 69.5ms
# Speed: 3.5ms preprocess, 69.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 64.6ms
# Speed: 0.0ms preprocess, 64.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.2ms
# Speed: 1.5ms preprocess, 55.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.6ms
# Speed: 1.0ms preprocess, 52.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.4ms
# Speed: 1.0ms preprocess, 55.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 65.5ms
# Speed: 2.0ms preprocess, 65.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.4ms
# Speed: 1.0ms preprocess, 55.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.6ms
# Speed: 1.0ms preprocess, 57.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.1ms
# Speed: 1.1ms preprocess, 59.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 57.7ms
# Speed: 2.0ms preprocess, 57.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 53.8ms
# Speed: 1.0ms preprocess, 53.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 55.2ms
# Speed: 1.1ms preprocess, 55.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 55.1ms
# Speed: 2.1ms preprocess, 55.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 60.2ms
# Speed: 2.0ms preprocess, 60.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 56.4ms
# Speed: 2.1ms preprocess, 56.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 53.4ms
# Speed: 1.5ms preprocess, 53.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 64.1ms
# Speed: 1.0ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 61.4ms
# Speed: 2.2ms preprocess, 61.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 54.6ms
# Speed: 2.0ms preprocess, 54.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 56.7ms
# Speed: 1.0ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 57.7ms
# Speed: 2.1ms preprocess, 57.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 57.6ms
# Speed: 1.0ms preprocess, 57.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 63.0ms
# Speed: 1.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 69.6ms
# Speed: 2.0ms preprocess, 69.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 59.1ms
# Speed: 2.0ms preprocess, 59.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 61.9ms
# Speed: 2.0ms preprocess, 61.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 63.5ms
# Speed: 2.3ms preprocess, 63.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 75.7ms
# Speed: 1.0ms preprocess, 75.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 60.3ms
# Speed: 1.4ms preprocess, 60.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 57.3ms
# Speed: 1.3ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 54.9ms
# Speed: 1.0ms preprocess, 54.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 59.7ms
# Speed: 2.0ms preprocess, 59.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 58.6ms
# Speed: 2.0ms preprocess, 58.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.0ms
# Speed: 2.6ms preprocess, 76.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.6ms
# Speed: 2.0ms preprocess, 57.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 70.8ms
# Speed: 1.0ms preprocess, 70.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.4ms
# Speed: 2.0ms preprocess, 56.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.2ms
# Speed: 2.0ms preprocess, 56.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.3ms
# Speed: 2.0ms preprocess, 56.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Afnan, 54.7ms
# Speed: 1.0ms preprocess, 54.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.3ms
# Speed: 1.0ms preprocess, 52.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.0ms
# Speed: 1.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.9ms
# Speed: 1.0ms preprocess, 56.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.7ms
# Speed: 2.0ms preprocess, 58.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.1ms
# Speed: 1.0ms preprocess, 52.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 95.8ms
# Speed: 3.0ms preprocess, 95.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.1ms
# Speed: 1.0ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.6ms
# Speed: 2.0ms preprocess, 51.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.7ms
# Speed: 2.3ms preprocess, 51.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 66.8ms
# Speed: 2.0ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.8ms
# Speed: 2.0ms preprocess, 57.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.7ms
# Speed: 1.0ms preprocess, 54.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.5ms
# Speed: 1.2ms preprocess, 54.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.6ms
# Speed: 1.0ms preprocess, 53.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.2ms
# Speed: 2.0ms preprocess, 53.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 69.0ms
# Speed: 2.5ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.1ms
# Speed: 1.0ms preprocess, 60.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.7ms
# Speed: 2.0ms preprocess, 57.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 66.2ms
# Speed: 2.0ms preprocess, 66.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 58.6ms
# Speed: 1.4ms preprocess, 58.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 58.7ms
# Speed: 1.5ms preprocess, 58.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.3ms
# Speed: 1.0ms preprocess, 61.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.8ms
# Speed: 1.0ms preprocess, 56.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 64.2ms
# Speed: 1.5ms preprocess, 64.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 68.7ms
# Speed: 2.0ms preprocess, 68.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.4ms
# Speed: 1.0ms preprocess, 59.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 70.8ms
# Speed: 1.5ms preprocess, 70.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.7ms
# Speed: 1.5ms preprocess, 55.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 67.1ms
# Speed: 2.3ms preprocess, 67.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 55.2ms
# Speed: 2.0ms preprocess, 55.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.6ms
# Speed: 2.0ms preprocess, 60.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.7ms
# Speed: 1.1ms preprocess, 59.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 94.0ms
# Speed: 1.0ms preprocess, 94.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 75.4ms
# Speed: 2.0ms preprocess, 75.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 57.6ms
# Speed: 1.1ms preprocess, 57.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 59.2ms
# Speed: 1.6ms preprocess, 59.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.1ms
# Speed: 1.0ms preprocess, 52.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 55.0ms
# Speed: 0.9ms preprocess, 55.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 53.6ms
# Speed: 2.0ms preprocess, 53.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 54.8ms
# Speed: 2.4ms preprocess, 54.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 83.4ms
# Speed: 2.0ms preprocess, 83.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 53.3ms
# Speed: 2.5ms preprocess, 53.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.9ms
# Speed: 2.0ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 52.4ms
# Speed: 1.0ms preprocess, 52.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 51.9ms
# Speed: 2.0ms preprocess, 51.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 68.8ms
# Speed: 2.3ms preprocess, 68.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 54.3ms
# Speed: 1.0ms preprocess, 54.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 53.5ms
# Speed: 3.0ms preprocess, 53.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 60.7ms
# Speed: 2.0ms preprocess, 60.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 58.3ms
# Speed: 1.0ms preprocess, 58.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 56.1ms
# Speed: 2.0ms preprocess, 56.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 98.0ms
# Speed: 2.5ms preprocess, 98.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 58.1ms
# Speed: 1.0ms preprocess, 58.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 55.9ms
# Speed: 1.0ms preprocess, 55.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 55.5ms
# Speed: 1.7ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 61.9ms
# Speed: 2.5ms preprocess, 61.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 53.2ms
# Speed: 1.9ms preprocess, 53.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Teriaq-Intense, 55.2ms
# Speed: 1.0ms preprocess, 55.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)

# %%
# Out:
# <function dir>
